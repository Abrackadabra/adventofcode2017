# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import requests

day_num = 16

cookies = {
    'session': '53616c7465645f5f465a94508e1037cf931dedaf44e298b1be500ec71305ff01432a6584b1fe922ea5bab725d96f17b1'
}

url = f'http://adventofcode.com/2017/day/{day_num}/input'

r = requests.get(url, cookies=cookies)

lines = [i.strip() for i in r.text.split('\n')][:-1]

# %%
import subprocess
import re

# %%
for i in range(18, 26):
    print(subprocess.check_output(['cp', 'd17.ipynb', f'd{i}.ipynb']))
# Out:
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''

# %%
#perl -0p -i -e 's/day_num = 16/day_num = 17/g' d17.ipynb
for i in range(17, 26):
    print(subprocess.check_output(['perl', '-0p', '-i', '-e', f's/day_num = \d+/day_num = {i}/g', f'd{i}.ipynb']))
# Out:
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''
# b''

# %%
commands = lines[0].split(',')
commands[:5]
# Out:
# ['x12/14', 's11', 'x10/4', 's7', 'pb/o']

# %%
a = [chr(i) for i in range(ord('a'), ord('p') + 1)]
roll(a, 3)
# Out:
# array(['n', 'o', 'p', 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j',
#        'k', 'l', 'm'],
#       dtype='<U1')

# %%
a = array([chr(i) for i in range(ord('a'), ord('p') + 1)])

for command in commands:
    match = re.findall(r'^(.)((.*?)/(.*))?(.*)', command)[0]
    letter, _, arg1, arg2, arg3 = match
    
    if letter == 's':
        a = roll(a, int(arg3))
    elif letter == 'x':
        pos1 = int(arg1)
        pos2 = int(arg2)
        a[pos1], a[pos2] = a[pos2], a[pos1]
# Out:
# x12/14 ('x', '12/14', '12', '14', '')
# s11 ('s', '', '', '', '11')
# x10/4 ('x', '10/4', '10', '4', '')
# s7 ('s', '', '', '', '7')
# pb/o ('p', 'b/o', 'b', 'o', '')
# x12/7 ('x', '12/7', '12', '7', '')
# s5 ('s', '', '', '', '5')
# x3/10 ('x', '3/10', '3', '10', '')
# s10 ('s', '', '', '', '10')
# x6/4 ('x', '6/4', '6', '4', '')
# pk/a ('p', 'k/a', 'k', 'a', '')
# x14/8 ('x', '14/8', '14', '8', '')
# s2 ('s', '', '', '', '2')
# x10/5 ('x', '10/5', '10', '5', '')
# s6 ('s', '', '', '', '6')
# x9/6 ('x', '9/6', '9', '6', '')
# s10 ('s', '', '', '', '10')
# pm/b ('p', 'm/b', 'm', 'b', '')
# x3/7 ('x', '3/7', '3', '7', '')
# s1 ('s', '', '', '', '1')
# x5/12 ('x', '5/12', '5', '12', '')
# po/k ('p', 'o/k', 'o', 'k', '')
# x1/13 ('x', '1/13', '1', '13', '')
# pc/g ('p', 'c/g', 'c', 'g', '')
# x9/11 ('x', '9/11', '9', '11', '')
# pd/l ('p', 'd/l', 'd', 'l', '')
# x12/7 ('x', '12/7', '12', '7', '')
# s5 ('s', '', '', '', '5')
# x11/3 ('x', '11/3', '11', '3', '')
# s15 ('s', '', '', '', '15')
# x2/5 ('x', '2/5', '2', '5', '')
# pe/j ('p', 'e/j', 'e', 'j', '')
# x10/15 ('x', '10/15', '10', '15', '')
# s13 ('s', '', '', '', '13')
# x8/7 ('x', '8/7', '8', '7', '')
# pa/k ('p', 'a/k', 'a', 'k', '')
# s5 ('s', '', '', '', '5')
# x2/4 ('x', '2/4', '2', '4', '')
# pl/d ('p', 'l/d', 'l', 'd', '')
# x11/15 ('x', '11/15', '11', '15', '')
# s1 ('s', '', '', '', '1')
# x12/8 ('x', '12/8', '12', '8', '')
# s4 ('s', '', '', '', '4')
# x13/10 ('x', '13/10', '13', '10', '')
# pk/j ('p', 'k/j', 'k', 'j', '')
# x14/8 ('x', '14/8', '14', '8', '')
# s8 ('s', '', '', '', '8')
# x2/1 ('x', '2/1', '2', '1', '')
# s4 ('s', '', '', '', '4')
# x13/7 ('x', '13/7', '13', '7', '')
# s7 ('s', '', '', '', '7')
# x10/6 ('x', '10/6', '10', '6', '')
# s9 ('s', '', '', '', '9')
# x9/15 ('x', '9/15', '9', '15', '')
# pf/p ('p', 'f/p', 'f', 'p', '')
# x5/0 ('x', '5/0', '5', '0', '')
# pg/a ('p', 'g/a', 'g', 'a', '')
# s1 ('s', '', '', '', '1')
# x10/11 ('x', '10/11', '10', '11', '')
# pm/h ('p', 'm/h', 'm', 'h', '')
# x5/7 ('x', '5/7', '5', '7', '')
# s4 ('s', '', '', '', '4')
# x8/13 ('x', '8/13', '8', '13', '')
# s14 ('s', '', '', '', '14')
# x11/7 ('x', '11/7', '11', '7', '')
# s13 ('s', '', '', '', '13')
# x4/9 ('x', '4/9', '4', '9', '')
# s15 ('s', '', '', '', '15')
# x7/2 ('x', '7/2', '7', '2', '')
# s5 ('s', '', '', '', '5')
# x10/11 ('x', '10/11', '10', '11', '')
# s10 ('s', '', '', '', '10')
# x2/5 ('x', '2/5', '2', '5', '')
# s8 ('s', '', '', '', '8')
# x3/14 ('x', '3/14', '3', '14', '')
# s6 ('s', '', '', '', '6')
# x13/12 ('x', '13/12', '13', '12', '')
# s7 ('s', '', '', '', '7')
# x7/8 ('x', '7/8', '7', '8', '')
# s2 ('s', '', '', '', '2')
# x14/4 ('x', '14/4', '14', '4', '')
# pc/e ('p', 'c/e', 'c', 'e', '')
# s13 ('s', '', '', '', '13')
# x7/15 ('x', '7/15', '7', '15', '')
# s14 ('s', '', '', '', '14')
# x5/10 ('x', '5/10', '5', '10', '')
# s15 ('s', '', '', '', '15')
# x13/2 ('x', '13/2', '13', '2', '')
# s8 ('s', '', '', '', '8')
# pk/o ('p', 'k/o', 'k', 'o', '')
# x6/10 ('x', '6/10', '6', '10', '')
# s15 ('s', '', '', '', '15')
# x13/12 ('x', '13/12', '13', '12', '')
# pi/m ('p', 'i/m', 'i', 'm', '')
# x0/1 ('x', '0/1', '0', '1', '')
# s9 ('s', '', '', '', '9')
# x13/8 ('x', '13/8', '13', '8', '')
# pg/a ('p', 'g/a', 'g', 'a', '')
# x5/0 ('x', '5/0', '5', '0', '')
# s11 ('s', '', '', '', '11')
# x13/4 ('x', '13/4', '13', '4', '')
# pl/m ('p', 'l/m', 'l', 'm', '')
# x15/8 ('x', '15/8', '15', '8', '')
# pc/e ('p', 'c/e', 'c', 'e', '')
# s3 ('s', '', '', '', '3')
# x1/13 ('x', '1/13', '1', '13', '')
# s3 ('s', '', '', '', '3')
# x8/14 ('x', '8/14', '8', '14', '')
# pp/k ('p', 'p/k', 'p', 'k', '')
# x7/3 ('x', '7/3', '7', '3', '')
# s11 ('s', '', '', '', '11')
# x5/13 ('x', '5/13', '5', '13', '')
# pb/h ('p', 'b/h', 'b', 'h', '')
# x9/15 ('x', '9/15', '9', '15', '')
# s5 ('s', '', '', '', '5')
# pp/i ('p', 'p/i', 'p', 'i', '')
# x11/12 ('x', '11/12', '11', '12', '')
# pl/j ('p', 'l/j', 'l', 'j', '')
# s12 ('s', '', '', '', '12')
# ph/n ('p', 'h/n', 'h', 'n', '')
# x4/1 ('x', '4/1', '4', '1', '')
# pe/a ('p', 'e/a', 'e', 'a', '')
# x9/10 ('x', '9/10', '9', '10', '')
# pp/f ('p', 'p/f', 'p', 'f', '')
# x4/5 ('x', '4/5', '4', '5', '')
# pg/j ('p', 'g/j', 'g', 'j', '')
# x10/3 ('x', '10/3', '10', '3', '')
# s5 ('s', '', '', '', '5')
# x7/0 ('x', '7/0', '7', '0', '')
# s1 ('s', '', '', '', '1')
# x4/8 ('x', '4/8', '4', '8', '')
# s9 ('s', '', '', '', '9')
# x1/3 ('x', '1/3', '1', '3', '')
# pe/c ('p', 'e/c', 'e', 'c', '')
# x9/10 ('x', '9/10', '9', '10', '')
# pj/o ('p', 'j/o', 'j', 'o', '')
# x14/12 ('x', '14/12', '14', '12', '')
# s5 ('s', '', '', '', '5')
# x3/6 ('x', '3/6', '3', '6', '')
# s15 ('s', '', '', '', '15')
# x0/4 ('x', '0/4', '0', '4', '')
# s14 ('s', '', '', '', '14')
# x10/6 ('x', '10/6', '10', '6', '')
# s9 ('s', '', '', '', '9')
# x15/2 ('x', '15/2', '15', '2', '')
# s12 ('s', '', '', '', '12')
# x8/0 ('x', '8/0', '8', '0', '')
# pm/p ('p', 'm/p', 'm', 'p', '')
# s7 ('s', '', '', '', '7')
# x5/6 ('x', '5/6', '5', '6', '')
# pa/c ('p', 'a/c', 'a', 'c', '')
# x11/10 ('x', '11/10', '11', '10', '')
# s2 ('s', '', '', '', '2')
# x15/6 ('x', '15/6', '15', '6', '')
# pg/l ('p', 'g/l', 'g', 'l', '')
# x13/14 ('x', '13/14', '13', '14', '')
# pd/j ('p', 'd/j', 'd', 'j', '')
# x7/15 ('x', '7/15', '7', '15', '')
# s12 ('s', '', '', '', '12')
# x9/1 ('x', '9/1', '9', '1', '')
# pi/m ('p', 'i/m', 'i', 'm', '')
# x8/7 ('x', '8/7', '8', '7', '')
# s5 ('s', '', '', '', '5')
# x2/1 ('x', '2/1', '2', '1', '')
# pj/o ('p', 'j/o', 'j', 'o', '')
# x4/11 ('x', '4/11', '4', '11', '')
# pb/i ('p', 'b/i', 'b', 'i', '')
# s1 ('s', '', '', '', '1')
# x8/3 ('x', '8/3', '8', '3', '')
# s4 ('s', '', '', '', '4')
# x11/5 ('x', '11/5', '11', '5', '')
# pp/o ('p', 'p/o', 'p', 'o', '')
# x15/13 ('x', '15/13', '15', '13', '')
# pm/h ('p', 'm/h', 'm', 'h', '')
# x6/14 ('x', '6/14', '6', '14', '')
# s3 ('s', '', '', '', '3')
# x5/11 ('x', '5/11', '5', '11', '')
# s2 ('s', '', '', '', '2')
# x14/6 ('x', '14/6', '14', '6', '')
# pk/f ('p', 'k/f', 'k', 'f', '')
# s13 ('s', '', '', '', '13')
# x13/10 ('x', '13/10', '13', '10', '')
# po/a ('p', 'o/a', 'o', 'a', '')
# x9/15 ('x', '9/15', '9', '15', '')
# s6 ('s', '', '', '', '6')
# x0/5 ('x', '0/5', '0', '5', '')
# s9 ('s', '', '', '', '9')
# x2/10 ('x', '2/10', '2', '10', '')
# pp/e ('p', 'p/e', 'p', 'e', '')
# x0/14 ('x', '0/14', '0', '14', '')
# pi/b ('p', 'i/b', 'i', 'b', '')
# x13/7 ('x', '13/7', '13', '7', '')
# s5 ('s', '', '', '', '5')
# x14/0 ('x', '14/0', '14', '0', '')
# s3 ('s', '', '', '', '3')
# x5/3 ('x', '5/3', '5', '3', '')
# s12 ('s', '', '', '', '12')
# x7/14 ('x', '7/14', '7', '14', '')
# pf/g ('p', 'f/g', 'f', 'g', '')
# x8/5 ('x', '8/5', '8', '5', '')
# pc/o ('p', 'c/o', 'c', 'o', '')
# x11/6 ('x', '11/6', '11', '6', '')
# s14 ('s', '', '', '', '14')
# x3/13 ('x', '3/13', '3', '13', '')
# pp/j ('p', 'p/j', 'p', 'j', '')
# x12/7 ('x', '12/7', '12', '7', '')
# s1 ('s', '', '', '', '1')
# x9/11 ('x', '9/11', '9', '11', '')
# pf/l ('p', 'f/l', 'f', 'l', '')
# x4/12 ('x', '4/12', '4', '12', '')
# s13 ('s', '', '', '', '13')
# x2/6 ('x', '2/6', '2', '6', '')
# s5 ('s', '', '', '', '5')
# x1/8 ('x', '1/8', '1', '8', '')
# pj/o ('p', 'j/o', 'j', 'o', '')
# x10/2 ('x', '10/2', '10', '2', '')
# s11 ('s', '', '', '', '11')
# x7/11 ('x', '7/11', '7', '11', '')
# pc/m ('p', 'c/m', 'c', 'm', '')
# x13/10 ('x', '13/10', '13', '10', '')
# s9 ('s', '', '', '', '9')
# x0/9 ('x', '0/9', '0', '9', '')
# pe/l ('p', 'e/l', 'e', 'l', '')
# x8/12 ('x', '8/12', '8', '12', '')
# s3 ('s', '', '', '', '3')
# x11/9 ('x', '11/9', '11', '9', '')
# s2 ('s', '', '', '', '2')
# x0/12 ('x', '0/12', '0', '12', '')
# pn/a ('p', 'n/a', 'n', 'a', '')
# x7/6 ('x', '7/6', '7', '6', '')
# pi/j ('p', 'i/j', 'i', 'j', '')
# s7 ('s', '', '', '', '7')
# x2/12 ('x', '2/12', '2', '12', '')
# pl/e ('p', 'l/e', 'l', 'e', '')
# x14/7 ('x', '14/7', '14', '7', '')
# s3 ('s', '', '', '', '3')
# x9/5 ('x', '9/5', '9', '5', '')
# s11 ('s', '', '', '', '11')
# x4/1 ('x', '4/1', '4', '1', '')
# pc/k ('p', 'c/k', 'c', 'k', '')
# x15/8 ('x', '15/8', '15', '8', '')
# s14 ('s', '', '', '', '14')
# x6/1 ('x', '6/1', '6', '1', '')
# pf/h ('p', 'f/h', 'f', 'h', '')
# x3/4 ('x', '3/4', '3', '4', '')
# s12 ('s', '', '', '', '12')
# x14/2 ('x', '14/2', '14', '2', '')
# pl/c ('p', 'l/c', 'l', 'c', '')
# x0/10 ('x', '0/10', '0', '10', '')
# pj/p ('p', 'j/p', 'j', 'p', '')
# x15/8 ('x', '15/8', '15', '8', '')
# s1 ('s', '', '', '', '1')
# x2/14 ('x', '2/14', '2', '14', '')
# s10 ('s', '', '', '', '10')
# x13/9 ('x', '13/9', '13', '9', '')
# s3 ('s', '', '', '', '3')
# x12/1 ('x', '12/1', '12', '1', '')
# pe/g ('p', 'e/g', 'e', 'g', '')
# x8/7 ('x', '8/7', '8', '7', '')
# pd/n ('p', 'd/n', 'd', 'n', '')
# x2/3 ('x', '2/3', '2', '3', '')
# pc/i ('p', 'c/i', 'c', 'i', '')
# x9/13 ('x', '9/13', '9', '13', '')
# po/m ('p', 'o/m', 'o', 'm', '')
# x12/15 ('x', '12/15', '12', '15', '')
# ph/c ('p', 'h/c', 'h', 'c', '')
# x0/1 ('x', '0/1', '0', '1', '')
# pl/e ('p', 'l/e', 'l', 'e', '')
# x7/11 ('x', '7/11', '7', '11', '')
# po/j ('p', 'o/j', 'o', 'j', '')
# x6/14 ('x', '6/14', '6', '14', '')
# s5 ('s', '', '', '', '5')
# x10/7 ('x', '10/7', '10', '7', '')
# s12 ('s', '', '', '', '12')
# x9/4 ('x', '9/4', '9', '4', '')
# pm/e ('p', 'm/e', 'm', 'e', '')
# x2/0 ('x', '2/0', '2', '0', '')
# s4 ('s', '', '', '', '4')
# x8/9 ('x', '8/9', '8', '9', '')
# pa/l ('p', 'a/l', 'a', 'l', '')
# s9 ('s', '', '', '', '9')
# x3/6 ('x', '3/6', '3', '6', '')
# s12 ('s', '', '', '', '12')
# x14/11 ('x', '14/11', '14', '11', '')
# s12 ('s', '', '', '', '12')
# x13/9 ('x', '13/9', '13', '9', '')
# s13 ('s', '', '', '', '13')
# x14/3 ('x', '14/3', '14', '3', '')
# s1 ('s', '', '', '', '1')
# pc/o ('p', 'c/o', 'c', 'o', '')
# x7/1 ('x', '7/1', '7', '1', '')
# s1 ('s', '', '', '', '1')
# x2/11 ('x', '2/11', '2', '11', '')
# s14 ('s', '', '', '', '14')
# x12/5 ('x', '12/5', '12', '5', '')
# s11 ('s', '', '', '', '11')
# x3/9 ('x', '3/9', '3', '9', '')
# pp/a ('p', 'p/a', 'p', 'a', '')
# x7/14 ('x', '7/14', '7', '14', '')
# pi/l ('p', 'i/l', 'i', 'l', '')
# x2/4 ('x', '2/4', '2', '4', '')
# pb/d ('p', 'b/d', 'b', 'd', '')
# x15/3 ('x', '15/3', '15', '3', '')
# pc/e ('p', 'c/e', 'c', 'e', '')
# x2/9 ('x', '2/9', '2', '9', '')
# s5 ('s', '', '', '', '5')
# x13/12 ('x', '13/12', '13', '12', '')
# s4 ('s', '', '', '', '4')
# x6/1 ('x', '6/1', '6', '1', '')
# s7 ('s', '', '', '', '7')
# x2/15 ('x', '2/15', '2', '15', '')
# pj/k ('p', 'j/k', 'j', 'k', '')
# x8/6 ('x', '8/6', '8', '6', '')
# s15 ('s', '', '', '', '15')
# x5/0 ('x', '5/0', '5', '0', '')
# s4 ('s', '', '', '', '4')
# x7/11 ('x', '7/11', '7', '11', '')
# s12 ('s', '', '', '', '12')
# x8/1 ('x', '8/1', '8', '1', '')
# pf/d ('p', 'f/d', 'f', 'd', '')
# x6/2 ('x', '6/2', '6', '2', '')
# pl/b ('p', 'l/b', 'l', 'b', '')
# x10/9 ('x', '10/9', '10', '9', '')
# s10 ('s', '', '', '', '10')
# x3/7 ('x', '3/7', '3', '7', '')
# pd/f ('p', 'd/f', 'd', 'f', '')
# x14/8 ('x', '14/8', '14', '8', '')
# pa/b ('p', 'a/b', 'a', 'b', '')
# x1/11 ('x', '1/11', '1', '11', '')
# pj/h ('p', 'j/h', 'j', 'h', '')
# x2/6 ('x', '2/6', '2', '6', '')
# s14 ('s', '', '', '', '14')
# x7/0 ('x', '7/0', '7', '0', '')
# pn/a ('p', 'n/a', 'n', 'a', '')
# x4/8 ('x', '4/8', '4', '8', '')
# s2 ('s', '', '', '', '2')
# ph/l ('p', 'h/l', 'h', 'l', '')
# x11/0 ('x', '11/0', '11', '0', '')
# pg/i ('p', 'g/i', 'g', 'i', '')
# x9/15 ('x', '9/15', '9', '15', '')
# pb/n ('p', 'b/n', 'b', 'n', '')
# x12/7 ('x', '12/7', '12', '7', '')
# s10 ('s', '', '', '', '10')
# x9/6 ('x', '9/6', '9', '6', '')
# pd/f ('p', 'd/f', 'd', 'f', '')
# x15/2 ('x', '15/2', '15', '2', '')
# s14 ('s', '', '', '', '14')
# x14/10 ('x', '14/10', '14', '10', '')
# s9 ('s', '', '', '', '9')
# x13/0 ('x', '13/0', '13', '0', '')
# po/l ('p', 'o/l', 'o', 'l', '')
# x6/11 ('x', '6/11', '6', '11', '')
# s14 ('s', '', '', '', '14')
# x2/5 ('x', '2/5', '2', '5', '')
# s11 ('s', '', '', '', '11')
# x12/0 ('x', '12/0', '12', '0', '')
# pj/b ('p', 'j/b', 'j', 'b', '')
# s8 ('s', '', '', '', '8')
# x4/6 ('x', '4/6', '4', '6', '')
# s7 ('s', '', '', '', '7')
# x1/7 ('x', '1/7', '1', '7', '')
# s1 ('s', '', '', '', '1')
# x11/8 ('x', '11/8', '11', '8', '')
# s11 ('s', '', '', '', '11')
# x1/15 ('x', '1/15', '1', '15', '')
# pk/i ('p', 'k/i', 'k', 'i', '')
# x9/5 ('x', '9/5', '9', '5', '')
# pc/l ('p', 'c/l', 'c', 'l', '')
# s7 ('s', '', '', '', '7')
# x0/11 ('x', '0/11', '0', '11', '')
# pp/a ('p', 'p/a', 'p', 'a', '')
# s1 ('s', '', '', '', '1')
# x8/9 ('x', '8/9', '8', '9', '')
# pl/n ('p', 'l/n', 'l', 'n', '')
# x0/11 ('x', '0/11', '0', '11', '')
# s2 ('s', '', '', '', '2')
# x10/13 ('x', '10/13', '10', '13', '')
# s11 ('s', '', '', '', '11')
# x0/6 ('x', '0/6', '0', '6', '')
# pg/f ('p', 'g/f', 'g', 'f', '')
# x1/7 ('x', '1/7', '1', '7', '')
# pp/a ('p', 'p/a', 'p', 'a', '')
# x8/3 ('x', '8/3', '8', '3', '')
# s15 ('s', '', '', '', '15')
# x0/11 ('x', '0/11', '0', '11', '')
# s8 ('s', '', '', '', '8')
# x15/3 ('x', '15/3', '15', '3', '')
# s2 ('s', '', '', '', '2')
# x0/8 ('x', '0/8', '0', '8', '')
# pl/g ('p', 'l/g', 'l', 'g', '')
# x12/9 ('x', '12/9', '12', '9', '')
# s8 ('s', '', '', '', '8')
# x8/5 ('x', '8/5', '8', '5', '')
# s1 ('s', '', '', '', '1')
# x2/9 ('x', '2/9', '2', '9', '')
# s1 ('s', '', '', '', '1')
# x6/8 ('x', '6/8', '6', '8', '')
# s5 ('s', '', '', '', '5')
# x12/11 ('x', '12/11', '12', '11', '')
# pp/e ('p', 'p/e', 'p', 'e', '')
# s6 ('s', '', '', '', '6')
# x1/5 ('x', '1/5', '1', '5', '')
# s8 ('s', '', '', '', '8')
# x2/10 ('x', '2/10', '2', '10', '')
# po/k ('p', 'o/k', 'o', 'k', '')
# x3/11 ('x', '3/11', '3', '11', '')
# s13 ('s', '', '', '', '13')
# x4/6 ('x', '4/6', '4', '6', '')
# pe/l ('p', 'e/l', 'e', 'l', '')
# x14/5 ('x', '14/5', '14', '5', '')
# s12 ('s', '', '', '', '12')
# x8/10 ('x', '8/10', '8', '10', '')
# s11 ('s', '', '', '', '11')
# x5/4 ('x', '5/4', '5', '4', '')
# pf/b ('p', 'f/b', 'f', 'b', '')
# x10/14 ('x', '10/14', '10', '14', '')
# po/j ('p', 'o/j', 'o', 'j', '')
# s7 ('s', '', '', '', '7')
# x9/7 ('x', '9/7', '9', '7', '')
# s2 ('s', '', '', '', '2')
# x15/6 ('x', '15/6', '15', '6', '')
# s14 ('s', '', '', '', '14')
# x14/1 ('x', '14/1', '14', '1', '')
# pk/n ('p', 'k/n', 'k', 'n', '')
# x13/9 ('x', '13/9', '13', '9', '')
# pm/f ('p', 'm/f', 'm', 'f', '')
# x4/14 ('x', '4/14', '4', '14', '')
# s7 ('s', '', '', '', '7')
# x13/9 ('x', '13/9', '13', '9', '')
# pp/n ('p', 'p/n', 'p', 'n', '')
# x11/14 ('x', '11/14', '11', '14', '')
# pl/o ('p', 'l/o', 'l', 'o', '')
# x4/2 ('x', '4/2', '4', '2', '')
# s3 ('s', '', '', '', '3')
# x11/13 ('x', '11/13', '11', '13', '')
# s5 ('s', '', '', '', '5')
# x8/6 ('x', '8/6', '8', '6', '')
# s5 ('s', '', '', '', '5')
# x9/4 ('x', '9/4', '9', '4', '')
# s2 ('s', '', '', '', '2')
# x1/7 ('x', '1/7', '1', '7', '')
# pb/d ('p', 'b/d', 'b', 'd', '')
# x2/4 ('x', '2/4', '2', '4', '')
# pe/h ('p', 'e/h', 'e', 'h', '')
# x0/3 ('x', '0/3', '0', '3', '')
# po/g ('p', 'o/g', 'o', 'g', '')
# x13/11 ('x', '13/11', '13', '11', '')
# pl/c ('p', 'l/c', 'l', 'c', '')
# s6 ('s', '', '', '', '6')
# x3/15 ('x', '3/15', '3', '15', '')
# pj/o ('p', 'j/o', 'j', 'o', '')
# s15 ('s', '', '', '', '15')
# x9/2 ('x', '9/2', '9', '2', '')
# s5 ('s', '', '', '', '5')
# x6/0 ('x', '6/0', '6', '0', '')
# s1 ('s', '', '', '', '1')
# x14/4 ('x', '14/4', '14', '4', '')
# s6 ('s', '', '', '', '6')
# x7/15 ('x', '7/15', '7', '15', '')
# s7 ('s', '', '', '', '7')
# x3/1 ('x', '3/1', '3', '1', '')
# s6 ('s', '', '', '', '6')
# x14/12 ('x', '14/12', '14', '12', '')
# s3 ('s', '', '', '', '3')
# x9/11 ('x', '9/11', '9', '11', '')
# s8 ('s', '', '', '', '8')
# x15/8 ('x', '15/8', '15', '8', '')
# pd/f ('p', 'd/f', 'd', 'f', '')
# x0/10 ('x', '0/10', '0', '10', '')
# pm/j ('p', 'm/j', 'm', 'j', '')
# x3/1 ('x', '3/1', '3', '1', '')
# pf/a ('p', 'f/a', 'f', 'a', '')
# x0/7 ('x', '0/7', '0', '7', '')
# po/n ('p', 'o/n', 'o', 'n', '')
# x15/11 ('x', '15/11', '15', '11', '')
# pm/j ('p', 'm/j', 'm', 'j', '')
# x7/13 ('x', '7/13', '7', '13', '')
# s13 ('s', '', '', '', '13')
# x1/3 ('x', '1/3', '1', '3', '')
# s9 ('s', '', '', '', '9')
# x2/7 ('x', '2/7', '2', '7', '')
# s10 ('s', '', '', '', '10')
# x1/13 ('x', '1/13', '1', '13', '')
# s14 ('s', '', '', '', '14')
# x11/14 ('x', '11/14', '11', '14', '')
# s5 ('s', '', '', '', '5')
# x6/2 ('x', '6/2', '6', '2', '')
# po/d ('p', 'o/d', 'o', 'd', '')
# x14/11 ('x', '14/11', '14', '11', '')
# s1 ('s', '', '', '', '1')
# x5/3 ('x', '5/3', '5', '3', '')
# s2 ('s', '', '', '', '2')
# x8/11 ('x', '8/11', '8', '11', '')
# pk/b ('p', 'k/b', 'k', 'b', '')
# s3 ('s', '', '', '', '3')
# x14/12 ('x', '14/12', '14', '12', '')
# pe/g ('p', 'e/g', 'e', 'g', '')
# x10/15 ('x', '10/15', '10', '15', '')
# s2 ('s', '', '', '', '2')
# x14/6 ('x', '14/6', '14', '6', '')
# s7 ('s', '', '', '', '7')
# x3/15 ('x', '3/15', '3', '15', '')
# s12 ('s', '', '', '', '12')
# x4/7 ('x', '4/7', '4', '7', '')
# s13 ('s', '', '', '', '13')
# x1/2 ('x', '1/2', '1', '2', '')
# s6 ('s', '', '', '', '6')
# x11/14 ('x', '11/14', '11', '14', '')
# s14 ('s', '', '', '', '14')
# x7/9 ('x', '7/9', '7', '9', '')
# s7 ('s', '', '', '', '7')
# x1/13 ('x', '1/13', '1', '13', '')
# pj/n ('p', 'j/n', 'j', 'n', '')
# x7/4 ('x', '7/4', '7', '4', '')
# s7 ('s', '', '', '', '7')
# x10/0 ('x', '10/0', '10', '0', '')
# s2 ('s', '', '', '', '2')
# x15/11 ('x', '15/11', '15', '11', '')
# pp/k ('p', 'p/k', 'p', 'k', '')
# x9/6 ('x', '9/6', '9', '6', '')
# pm/n ('p', 'm/n', 'm', 'n', '')
# x11/5 ('x', '11/5', '11', '5', '')
# pp/i ('p', 'p/i', 'p', 'i', '')
# x13/1 ('x', '13/1', '13', '1', '')
# s3 ('s', '', '', '', '3')
# x15/11 ('x', '15/11', '15', '11', '')
# pd/n ('p', 'd/n', 'd', 'n', '')
# x2/0 ('x', '2/0', '2', '0', '')
# pc/b ('p', 'c/b', 'c', 'b', '')
# x11/5 ('x', '11/5', '11', '5', '')
# pj/n ('p', 'j/n', 'j', 'n', '')
# x3/14 ('x', '3/14', '3', '14', '')
# pk/c ('p', 'k/c', 'k', 'c', '')
# x0/1 ('x', '0/1', '0', '1', '')
# pn/i ('p', 'n/i', 'n', 'i', '')
# x2/7 ('x', '2/7', '2', '7', '')
# ph/l ('p', 'h/l', 'h', 'l', '')
# x12/8 ('x', '12/8', '12', '8', '')
# pk/i ('p', 'k/i', 'k', 'i', '')
# x11/15 ('x', '11/15', '11', '15', '')
# s8 ('s', '', '', '', '8')
# x4/13 ('x', '4/13', '4', '13', '')
# s10 ('s', '', '', '', '10')
# x11/3 ('x', '11/3', '11', '3', '')
# s12 ('s', '', '', '', '12')
# x2/6 ('x', '2/6', '2', '6', '')
# pl/c ('p', 'l/c', 'l', 'c', '')
# s9 ('s', '', '', '', '9')
# pp/n ('p', 'p/n', 'p', 'n', '')
# x14/7 ('x', '14/7', '14', '7', '')
# s8 ('s', '', '', '', '8')
# x11/9 ('x', '11/9', '11', '9', '')
# pj/i ('p', 'j/i', 'j', 'i', '')
# x7/12 ('x', '7/12', '7', '12', '')
# s9 ('s', '', '', '', '9')
# x8/9 ('x', '8/9', '8', '9', '')
# pe/h ('p', 'e/h', 'e', 'h', '')
# s7 ('s', '', '', '', '7')
# x13/5 ('x', '13/5', '13', '5', '')
# pm/p ('p', 'm/p', 'm', 'p', '')
# x10/9 ('x', '10/9', '10', '9', '')
# s13 ('s', '', '', '', '13')
# x8/0 ('x', '8/0', '8', '0', '')
# s4 ('s', '', '', '', '4')
# x10/12 ('x', '10/12', '10', '12', '')
# s7 ('s', '', '', '', '7')
# x11/6 ('x', '11/6', '11', '6', '')
# s4 ('s', '', '', '', '4')
# pl/c ('p', 'l/c', 'l', 'c', '')
# x14/4 ('x', '14/4', '14', '4', '')
# pd/n ('p', 'd/n', 'd', 'n', '')
# s7 ('s', '', '', '', '7')
# x6/1 ('x', '6/1', '6', '1', '')
# s7 ('s', '', '', '', '7')
# x13/9 ('x', '13/9', '13', '9', '')
# pp/f ('p', 'p/f', 'p', 'f', '')
# x8/2 ('x', '8/2', '8', '2', '')
# s2 ('s', '', '', '', '2')
# x4/6 ('x', '4/6', '4', '6', '')
# s11 ('s', '', '', '', '11')
# x15/9 ('x', '15/9', '15', '9', '')
# pg/e ('p', 'g/e', 'g', 'e', '')
# x7/2 ('x', '7/2', '7', '2', '')
# pn/f ('p', 'n/f', 'n', 'f', '')
# x10/8 ('x', '10/8', '10', '8', '')
# s10 ('s', '', '', '', '10')
# ph/j ('p', 'h/j', 'h', 'j', '')
# x14/7 ('x', '14/7', '14', '7', '')
# s9 ('s', '', '', '', '9')
# pk/i ('p', 'k/i', 'k', 'i', '')
# x13/0 ('x', '13/0', '13', '0', '')
# pb/g ('p', 'b/g', 'b', 'g', '')
# x2/6 ('x', '2/6', '2', '6', '')
# s9 ('s', '', '', '', '9')
# x12/5 ('x', '12/5', '12', '5', '')
# pc/a ('p', 'c/a', 'c', 'a', '')
# x6/2 ('x', '6/2', '6', '2', '')
# s4 ('s', '', '', '', '4')
# pe/k ('p', 'e/k', 'e', 'k', '')
# x5/12 ('x', '5/12', '5', '12', '')
# s4 ('s', '', '', '', '4')
# x0/10 ('x', '0/10', '0', '10', '')
# pp/a ('p', 'p/a', 'p', 'a', '')
# x15/4 ('x', '15/4', '15', '4', '')
# s15 ('s', '', '', '', '15')
# x11/14 ('x', '11/14', '11', '14', '')
# pf/e ('p', 'f/e', 'f', 'e', '')
# x8/6 ('x', '8/6', '8', '6', '')
# s2 ('s', '', '', '', '2')
# x1/3 ('x', '1/3', '1', '3', '')
# pn/o ('p', 'n/o', 'n', 'o', '')
# s10 ('s', '', '', '', '10')
# x8/9 ('x', '8/9', '8', '9', '')
# s12 ('s', '', '', '', '12')
# x11/14 ('x', '11/14', '11', '14', '')
# pk/a ('p', 'k/a', 'k', 'a', '')
# x13/7 ('x', '13/7', '13', '7', '')
# ph/b ('p', 'h/b', 'h', 'b', '')
# x9/11 ('x', '9/11', '9', '11', '')
# s5 ('s', '', '', '', '5')
# x15/4 ('x', '15/4', '15', '4', '')
# s4 ('s', '', '', '', '4')
# x8/1 ('x', '8/1', '8', '1', '')
# pg/p ('p', 'g/p', 'g', 'p', '')
# x12/15 ('x', '12/15', '12', '15', '')
# pn/c ('p', 'n/c', 'n', 'c', '')
# x3/13 ('x', '3/13', '3', '13', '')
# s15 ('s', '', '', '', '15')
# x2/8 ('x', '2/8', '2', '8', '')
# po/f ('p', 'o/f', 'o', 'f', '')
# x15/9 ('x', '15/9', '15', '9', '')
# s3 ('s', '', '', '', '3')
# x3/12 ('x', '3/12', '3', '12', '')
# s10 ('s', '', '', '', '10')
# x13/6 ('x', '13/6', '13', '6', '')
# pg/b ('p', 'g/b', 'g', 'b', '')
# x1/3 ('x', '1/3', '1', '3', '')
# s5 ('s', '', '', '', '5')
# x5/10 ('x', '5/10', '5', '10', '')
# s14 ('s', '', '', '', '14')
# x12/7 ('x', '12/7', '12', '7', '')
# s6 ('s', '', '', '', '6')
# x1/4 ('x', '1/4', '1', '4', '')
# s1 ('s', '', '', '', '1')
# x10/8 ('x', '10/8', '10', '8', '')
# s1 ('s', '', '', '', '1')
# x2/15 ('x', '2/15', '2', '15', '')
# s13 ('s', '', '', '', '13')
# x7/14 ('x', '7/14', '7', '14', '')
# pj/f ('p', 'j/f', 'j', 'f', '')
# x3/13 ('x', '3/13', '3', '13', '')
# s3 ('s', '', '', '', '3')
# x2/14 ('x', '2/14', '2', '14', '')
# pp/a ('p', 'p/a', 'p', 'a', '')
# x9/4 ('x', '9/4', '9', '4', '')
# pd/h ('p', 'd/h', 'd', 'h', '')
# x15/5 ('x', '15/5', '15', '5', '')
# s13 ('s', '', '', '', '13')
# x3/6 ('x', '3/6', '3', '6', '')
# pj/m ('p', 'j/m', 'j', 'm', '')
# x10/14 ('x', '10/14', '10', '14', '')
# s1 ('s', '', '', '', '1')
# x4/6 ('x', '4/6', '4', '6', '')
# s8 ('s', '', '', '', '8')
# x5/11 ('x', '5/11', '5', '11', '')
# po/h ('p', 'o/h', 'o', 'h', '')
# x9/12 ('x', '9/12', '9', '12', '')
# pc/n ('p', 'c/n', 'c', 'n', '')
# x5/10 ('x', '5/10', '5', '10', '')
# s10 ('s', '', '', '', '10')
# pi/g ('p', 'i/g', 'i', 'g', '')
# x7/8 ('x', '7/8', '7', '8', '')
# pa/f ('p', 'a/f', 'a', 'f', '')
# x9/13 ('x', '9/13', '9', '13', '')
# s5 ('s', '', '', '', '5')
# pp/k ('p', 'p/k', 'p', 'k', '')
# x2/5 ('x', '2/5', '2', '5', '')
# pc/d ('p', 'c/d', 'c', 'd', '')
# x14/10 ('x', '14/10', '14', '10', '')
# pg/k ('p', 'g/k', 'g', 'k', '')
# x4/3 ('x', '4/3', '4', '3', '')
# s15 ('s', '', '', '', '15')
# x15/9 ('x', '15/9', '15', '9', '')
# pf/n ('p', 'f/n', 'f', 'n', '')
# x14/7 ('x', '14/7', '14', '7', '')
# pi/b ('p', 'i/b', 'i', 'b', '')
# x15/5 ('x', '15/5', '15', '5', '')
# pm/f ('p', 'm/f', 'm', 'f', '')
# x4/7 ('x', '4/7', '4', '7', '')
# s14 ('s', '', '', '', '14')
# x8/6 ('x', '8/6', '8', '6', '')
# s3 ('s', '', '', '', '3')
# pc/a ('p', 'c/a', 'c', 'a', '')
# x11/2 ('x', '11/2', '11', '2', '')
# s11 ('s', '', '', '', '11')
# x12/5 ('x', '12/5', '12', '5', '')
# pi/e ('p', 'i/e', 'i', 'e', '')
# x6/11 ('x', '6/11', '6', '11', '')
# s13 ('s', '', '', '', '13')
# x9/12 ('x', '9/12', '9', '12', '')
# pc/l ('p', 'c/l', 'c', 'l', '')
# x0/10 ('x', '0/10', '0', '10', '')
# s8 ('s', '', '', '', '8')
# x2/5 ('x', '2/5', '2', '5', '')
# s2 ('s', '', '', '', '2')
# x15/11 ('x', '15/11', '15', '11', '')
# pe/n ('p', 'e/n', 'e', 'n', '')
# x14/2 ('x', '14/2', '14', '2', '')
# pp/o ('p', 'p/o', 'p', 'o', '')
# s12 ('s', '', '', '', '12')
# x6/11 ('x', '6/11', '6', '11', '')
# s4 ('s', '', '', '', '4')
# x10/0 ('x', '10/0', '10', '0', '')
# s6 ('s', '', '', '', '6')
# x14/3 ('x', '14/3', '14', '3', '')
# s5 ('s', '', '', '', '5')
# pb/d ('p', 'b/d', 'b', 'd', '')
# x9/8 ('x', '9/8', '9', '8', '')
# ph/m ('p', 'h/m', 'h', 'm', '')
# s10 ('s', '', '', '', '10')
# x14/1 ('x', '14/1', '14', '1', '')
# pl/f ('p', 'l/f', 'l', 'f', '')
# x5/10 ('x', '5/10', '5', '10', '')
# pc/p ('p', 'c/p', 'c', 'p', '')
# x15/6 ('x', '15/6', '15', '6', '')
# pk/b ('p', 'k/b', 'k', 'b', '')
# x3/2 ('x', '3/2', '3', '2', '')
# ph/e ('p', 'h/e', 'h', 'e', '')
# x6/0 ('x', '6/0', '6', '0', '')
# pm/l ('p', 'm/l', 'm', 'l', '')
# x3/15 ('x', '3/15', '3', '15', '')
# s8 ('s', '', '', '', '8')
# x0/4 ('x', '0/4', '0', '4', '')
# pd/c ('p', 'd/c', 'd', 'c', '')
# x12/3 ('x', '12/3', '12', '3', '')
# s5 ('s', '', '', '', '5')
# x1/5 ('x', '1/5', '1', '5', '')
# pa/f ('p', 'a/f', 'a', 'f', '')
# x13/6 ('x', '13/6', '13', '6', '')
# s10 ('s', '', '', '', '10')
# x4/3 ('x', '4/3', '4', '3', '')
# po/c ('p', 'o/c', 'o', 'c', '')
# x7/13 ('x', '7/13', '7', '13', '')
# s7 ('s', '', '', '', '7')
# x14/2 ('x', '14/2', '14', '2', '')
# s15 ('s', '', '', '', '15')
# x3/6 ('x', '3/6', '3', '6', '')
# pi/g ('p', 'i/g', 'i', 'g', '')
# x1/2 ('x', '1/2', '1', '2', '')
# s11 ('s', '', '', '', '11')
# x6/15 ('x', '6/15', '6', '15', '')
# s12 ('s', '', '', '', '12')
# x9/1 ('x', '9/1', '9', '1', '')
# s2 ('s', '', '', '', '2')
# x2/12 ('x', '2/12', '2', '12', '')
# s4 ('s', '', '', '', '4')
# x7/6 ('x', '7/6', '7', '6', '')
# s13 ('s', '', '', '', '13')
# x13/9 ('x', '13/9', '13', '9', '')
# s1 ('s', '', '', '', '1')
# x6/10 ('x', '6/10', '6', '10', '')
# pn/k ('p', 'n/k', 'n', 'k', '')
# x3/1 ('x', '3/1', '3', '1', '')
# pf/b ('p', 'f/b', 'f', 'b', '')
# s12 ('s', '', '', '', '12')
# x14/7 ('x', '14/7', '14', '7', '')
# s10 ('s', '', '', '', '10')
# x2/5 ('x', '2/5', '2', '5', '')
# pp/l ('p', 'p/l', 'p', 'l', '')
# x13/12 ('x', '13/12', '13', '12', '')
# po/g ('p', 'o/g', 'o', 'g', '')
# x9/5 ('x', '9/5', '9', '5', '')
# pl/c ('p', 'l/c', 'l', 'c', '')
# s15 ('s', '', '', '', '15')
# x4/1 ('x', '4/1', '4', '1', '')
# s9 ('s', '', '', '', '9')
# x15/14 ('x', '15/14', '15', '14', '')
# s13 ('s', '', '', '', '13')
# x4/3 ('x', '4/3', '4', '3', '')
# s6 ('s', '', '', '', '6')
# pj/b ('p', 'j/b', 'j', 'b', '')
# x10/9 ('x', '10/9', '10', '9', '')
# s8 ('s', '', '', '', '8')
# x8/5 ('x', '8/5', '8', '5', '')
# s15 ('s', '', '', '', '15')
# x15/13 ('x', '15/13', '15', '13', '')
# s12 ('s', '', '', '', '12')
# x2/4 ('x', '2/4', '2', '4', '')
# pd/p ('p', 'd/p', 'd', 'p', '')
# x9/11 ('x', '9/11', '9', '11', '')
# s3 ('s', '', '', '', '3')
# x13/7 ('x', '13/7', '13', '7', '')
# s9 ('s', '', '', '', '9')
# x11/10 ('x', '11/10', '11', '10', '')
# s5 ('s', '', '', '', '5')
# x2/6 ('x', '2/6', '2', '6', '')
# s14 ('s', '', '', '', '14')
# x8/12 ('x', '8/12', '8', '12', '')
# ph/b ('p', 'h/b', 'h', 'b', '')
# s4 ('s', '', '', '', '4')
# x9/10 ('x', '9/10', '9', '10', '')
# s4 ('s', '', '', '', '4')
# x12/13 ('x', '12/13', '12', '13', '')
# pe/a ('p', 'e/a', 'e', 'a', '')
# x3/10 ('x', '3/10', '3', '10', '')
# pb/m ('p', 'b/m', 'b', 'm', '')
# x12/6 ('x', '12/6', '12', '6', '')
# pk/o ('p', 'k/o', 'k', 'o', '')
# x5/4 ('x', '5/4', '5', '4', '')
# pb/h ('p', 'b/h', 'b', 'h', '')
# x12/7 ('x', '12/7', '12', '7', '')
# s9 ('s', '', '', '', '9')
# x11/10 ('x', '11/10', '11', '10', '')
# s5 ('s', '', '', '', '5')
# x13/14 ('x', '13/14', '13', '14', '')
# pe/i ('p', 'e/i', 'e', 'i', '')
# x0/6 ('x', '0/6', '0', '6', '')
# ph/k ('p', 'h/k', 'h', 'k', '')
# x4/8 ('x', '4/8', '4', '8', '')
# pj/c ('p', 'j/c', 'j', 'c', '')
# s5 ('s', '', '', '', '5')
# x7/11 ('x', '7/11', '7', '11', '')
# pe/m ('p', 'e/m', 'e', 'm', '')
# x14/15 ('x', '14/15', '14', '15', '')
# s15 ('s', '', '', '', '15')
# x2/1 ('x', '2/1', '2', '1', '')
# ph/d ('p', 'h/d', 'h', 'd', '')
# s13 ('s', '', '', '', '13')
# x10/13 ('x', '10/13', '10', '13', '')
# s3 ('s', '', '', '', '3')
# x14/2 ('x', '14/2', '14', '2', '')
# s3 ('s', '', '', '', '3')
# x9/10 ('x', '9/10', '9', '10', '')
# pj/o ('p', 'j/o', 'j', 'o', '')
# x2/5 ('x', '2/5', '2', '5', '')
# s6 ('s', '', '', '', '6')
# x0/10 ('x', '0/10', '0', '10', '')
# s8 ('s', '', '', '', '8')
# x2/9 ('x', '2/9', '2', '9', '')
# s9 ('s', '', '', '', '9')
# x6/12 ('x', '6/12', '6', '12', '')
# pl/m ('p', 'l/m', 'l', 'm', '')
# x7/0 ('x', '7/0', '7', '0', '')
# pf/c ('p', 'f/c', 'f', 'c', '')
# x2/13 ('x', '2/13', '2', '13', '')
# pl/g ('p', 'l/g', 'l', 'g', '')
# x7/3 ('x', '7/3', '7', '3', '')
# pf/e ('p', 'f/e', 'f', 'e', '')
# x13/11 ('x', '13/11', '13', '11', '')
# s4 ('s', '', '', '', '4')
# x12/14 ('x', '12/14', '12', '14', '')
# pn/j ('p', 'n/j', 'n', 'j', '')
# x0/13 ('x', '0/13', '0', '13', '')
# pm/a ('p', 'm/a', 'm', 'a', '')
# s13 ('s', '', '', '', '13')
# x9/2 ('x', '9/2', '9', '2', '')
# pd/c ('p', 'd/c', 'd', 'c', '')
# x7/3 ('x', '7/3', '7', '3', '')
# s1 ('s', '', '', '', '1')
# x6/4 ('x', '6/4', '6', '4', '')
# s7 ('s', '', '', '', '7')
# x3/9 ('x', '3/9', '3', '9', '')
# s5 ('s', '', '', '', '5')
# x13/7 ('x', '13/7', '13', '7', '')
# ph/j ('p', 'h/j', 'h', 'j', '')
# x15/14 ('x', '15/14', '15', '14', '')
# pc/b ('p', 'c/b', 'c', 'b', '')
# x8/10 ('x', '8/10', '8', '10', '')
# s12 ('s', '', '', '', '12')
# x7/11 ('x', '7/11', '7', '11', '')
# s12 ('s', '', '', '', '12')
# x14/9 ('x', '14/9', '14', '9', '')
# s15 ('s', '', '', '', '15')
# x15/6 ('x', '15/6', '15', '6', '')
# po/p ('p', 'o/p', 'o', 'p', '')
# x12/0 ('x', '12/0', '12', '0', '')
# s15 ('s', '', '', '', '15')
# x7/15 ('x', '7/15', '7', '15', '')
# s9 ('s', '', '', '', '9')
# x6/5 ('x', '6/5', '6', '5', '')
# pf/i ('p', 'f/i', 'f', 'i', '')
# x15/1 ('x', '15/1', '15', '1', '')
# pc/e ('p', 'c/e', 'c', 'e', '')
# x11/2 ('x', '11/2', '11', '2', '')
# pf/i ('p', 'f/i', 'f', 'i', '')
# s3 ('s', '', '', '', '3')
# x5/0 ('x', '5/0', '5', '0', '')
# pc/k ('p', 'c/k', 'c', 'k', '')
# x6/14 ('x', '6/14', '6', '14', '')
# pi/m ('p', 'i/m', 'i', 'm', '')
# x11/4 ('x', '11/4', '11', '4', '')
# po/a ('p', 'o/a', 'o', 'a', '')
# x10/3 ('x', '10/3', '10', '3', '')
# s15 ('s', '', '', '', '15')
# x6/7 ('x', '6/7', '6', '7', '')
# pg/c ('p', 'g/c', 'g', 'c', '')
# x4/13 ('x', '4/13', '4', '13', '')
# pe/i ('p', 'e/i', 'e', 'i', '')
# x5/11 ('x', '5/11', '5', '11', '')
# s12 ('s', '', '', '', '12')
# x1/15 ('x', '1/15', '1', '15', '')
# s13 ('s', '', '', '', '13')
# x11/6 ('x', '11/6', '11', '6', '')
# pk/l ('p', 'k/l', 'k', 'l', '')
# x3/14 ('x', '3/14', '3', '14', '')
# pm/e ('p', 'm/e', 'm', 'e', '')
# x2/5 ('x', '2/5', '2', '5', '')
# s13 ('s', '', '', '', '13')
# x10/9 ('x', '10/9', '10', '9', '')
# s3 ('s', '', '', '', '3')
# x4/0 ('x', '4/0', '4', '0', '')
# pa/h ('p', 'a/h', 'a', 'h', '')
# x13/3 ('x', '13/3', '13', '3', '')
# s5 ('s', '', '', '', '5')
# x0/4 ('x', '0/4', '0', '4', '')
# s7 ('s', '', '', '', '7')
# x5/3 ('x', '5/3', '5', '3', '')
# s5 ('s', '', '', '', '5')
# x11/12 ('x', '11/12', '11', '12', '')
# s6 ('s', '', '', '', '6')
# x2/13 ('x', '2/13', '2', '13', '')
# pc/n ('p', 'c/n', 'c', 'n', '')
# x7/5 ('x', '7/5', '7', '5', '')
# pg/p ('p', 'g/p', 'g', 'p', '')
# x3/6 ('x', '3/6', '3', '6', '')
# pc/j ('p', 'c/j', 'c', 'j', '')
# x12/15 ('x', '12/15', '12', '15', '')
# pa/d ('p', 'a/d', 'a', 'd', '')
# x11/5 ('x', '11/5', '11', '5', '')
# s9 ('s', '', '', '', '9')
# x9/7 ('x', '9/7', '9', '7', '')
# ph/j ('p', 'h/j', 'h', 'j', '')
# x10/14 ('x', '10/14', '10', '14', '')
# s7 ('s', '', '', '', '7')
# x15/13 ('x', '15/13', '15', '13', '')
# s15 ('s', '', '', '', '15')
# x10/2 ('x', '10/2', '10', '2', '')
# pc/e ('p', 'c/e', 'c', 'e', '')
# x14/4 ('x', '14/4', '14', '4', '')
# s1 ('s', '', '', '', '1')
# x13/1 ('x', '13/1', '13', '1', '')
# s9 ('s', '', '', '', '9')
# x3/10 ('x', '3/10', '3', '10', '')
# pk/n ('p', 'k/n', 'k', 'n', '')
# x1/8 ('x', '1/8', '1', '8', '')
# s15 ('s', '', '', '', '15')
# x14/10 ('x', '14/10', '14', '10', '')
# s2 ('s', '', '', '', '2')
# x3/13 ('x', '3/13', '3', '13', '')
# pl/c ('p', 'l/c', 'l', 'c', '')
# x11/15 ('x', '11/15', '11', '15', '')
# s13 ('s', '', '', '', '13')
# x1/7 ('x', '1/7', '1', '7', '')
# pa/m ('p', 'a/m', 'a', 'm', '')
# x6/2 ('x', '6/2', '6', '2', '')
# pf/o ('p', 'f/o', 'f', 'o', '')
# x10/0 ('x', '10/0', '10', '0', '')
# s10 ('s', '', '', '', '10')
# x7/6 ('x', '7/6', '7', '6', '')
# pk/c ('p', 'k/c', 'k', 'c', '')
# x0/11 ('x', '0/11', '0', '11', '')
# s12 ('s', '', '', '', '12')
# x5/13 ('x', '5/13', '5', '13', '')
# s12 ('s', '', '', '', '12')
# x1/2 ('x', '1/2', '1', '2', '')
# pf/p ('p', 'f/p', 'f', 'p', '')
# x9/14 ('x', '9/14', '9', '14', '')
# s12 ('s', '', '', '', '12')
# x13/2 ('x', '13/2', '13', '2', '')
# s12 ('s', '', '', '', '12')
# x14/3 ('x', '14/3', '14', '3', '')
# pb/a ('p', 'b/a', 'b', 'a', '')
# x0/11 ('x', '0/11', '0', '11', '')
# ph/g ('p', 'h/g', 'h', 'g', '')
# x12/4 ('x', '12/4', '12', '4', '')
# pj/k ('p', 'j/k', 'j', 'k', '')
# x3/7 ('x', '3/7', '3', '7', '')
# s6 ('s', '', '', '', '6')
# x4/0 ('x', '4/0', '4', '0', '')
# pn/h ('p', 'n/h', 'n', 'h', '')
# s7 ('s', '', '', '', '7')
# x6/10 ('x', '6/10', '6', '10', '')
# pg/p ('p', 'g/p', 'g', 'p', '')
# x12/9 ('x', '12/9', '12', '9', '')
# ph/e ('p', 'h/e', 'h', 'e', '')
# x13/4 ('x', '13/4', '13', '4', '')
# pj/c ('p', 'j/c', 'j', 'c', '')
# x14/15 ('x', '14/15', '14', '15', '')
# pp/e ('p', 'p/e', 'p', 'e', '')
# s9 ('s', '', '', '', '9')
# x1/12 ('x', '1/12', '1', '12', '')
# pf/l ('p', 'f/l', 'f', 'l', '')
# x15/11 ('x', '15/11', '15', '11', '')
# s8 ('s', '', '', '', '8')
# x7/6 ('x', '7/6', '7', '6', '')
# pp/c ('p', 'p/c', 'p', 'c', '')
# x10/12 ('x', '10/12', '10', '12', '')
# pd/o ('p', 'd/o', 'd', 'o', '')
# x4/0 ('x', '4/0', '4', '0', '')
# pf/b ('p', 'f/b', 'f', 'b', '')
# s1 ('s', '', '', '', '1')
# x13/2 ('x', '13/2', '13', '2', '')
# pg/l ('p', 'g/l', 'g', 'l', '')
# x15/6 ('x', '15/6', '15', '6', '')
# pf/h ('p', 'f/h', 'f', 'h', '')
# x3/8 ('x', '3/8', '3', '8', '')
# pb/d ('p', 'b/d', 'b', 'd', '')
# x11/15 ('x', '11/15', '11', '15', '')
# s11 ('s', '', '', '', '11')
# x3/12 ('x', '3/12', '3', '12', '')
# s13 ('s', '', '', '', '13')
# x9/11 ('x', '9/11', '9', '11', '')
# pc/m ('p', 'c/m', 'c', 'm', '')
# x3/4 ('x', '3/4', '3', '4', '')
# ph/i ('p', 'h/i', 'h', 'i', '')
# s12 ('s', '', '', '', '12')
# x5/14 ('x', '5/14', '5', '14', '')
# s8 ('s', '', '', '', '8')
# x15/11 ('x', '15/11', '15', '11', '')
# s3 ('s', '', '', '', '3')
# x14/9 ('x', '14/9', '14', '9', '')
# s15 ('s', '', '', '', '15')
# x3/15 ('x', '3/15', '3', '15', '')
# s9 ('s', '', '', '', '9')
# x11/12 ('x', '11/12', '11', '12', '')
# s13 ('s', '', '', '', '13')
# x15/3 ('x', '15/3', '15', '3', '')
# s12 ('s', '', '', '', '12')
# x0/8 ('x', '0/8', '0', '8', '')
# s12 ('s', '', '', '', '12')
# x15/10 ('x', '15/10', '15', '10', '')
# s9 ('s', '', '', '', '9')
# x4/6 ('x', '4/6', '4', '6', '')
# s14 ('s', '', '', '', '14')
# x7/2 ('x', '7/2', '7', '2', '')
# s4 ('s', '', '', '', '4')
# x8/13 ('x', '8/13', '8', '13', '')
# s11 ('s', '', '', '', '11')
# x11/15 ('x', '11/15', '11', '15', '')
# s14 ('s', '', '', '', '14')
# x4/10 ('x', '4/10', '4', '10', '')
# pk/n ('p', 'k/n', 'k', 'n', '')
# s14 ('s', '', '', '', '14')
# x2/6 ('x', '2/6', '2', '6', '')
# s8 ('s', '', '', '', '8')
# pl/p ('p', 'l/p', 'l', 'p', '')
# s11 ('s', '', '', '', '11')
# pc/i ('p', 'c/i', 'c', 'i', '')
# x12/7 ('x', '12/7', '12', '7', '')
# s1 ('s', '', '', '', '1')
# x11/9 ('x', '11/9', '11', '9', '')
# s5 ('s', '', '', '', '5')
# x10/1 ('x', '10/1', '10', '1', '')
# pj/f ('p', 'j/f', 'j', 'f', '')
# x0/3 ('x', '0/3', '0', '3', '')
# pd/m ('p', 'd/m', 'd', 'm', '')
# s4 ('s', '', '', '', '4')
# x7/13 ('x', '7/13', '7', '13', '')
# pa/g ('p', 'a/g', 'a', 'g', '')
# x12/5 ('x', '12/5', '12', '5', '')
# s9 ('s', '', '', '', '9')
# pe/n ('p', 'e/n', 'e', 'n', '')
# x15/0 ('x', '15/0', '15', '0', '')
# pg/d ('p', 'g/d', 'g', 'd', '')
# x2/12 ('x', '2/12', '2', '12', '')
# pf/p ('p', 'f/p', 'f', 'p', '')
# x5/15 ('x', '5/15', '5', '15', '')
# s7 ('s', '', '', '', '7')
# x8/11 ('x', '8/11', '8', '11', '')
# pj/k ('p', 'j/k', 'j', 'k', '')
# x2/6 ('x', '2/6', '2', '6', '')
# s5 ('s', '', '', '', '5')
# x8/10 ('x', '8/10', '8', '10', '')
# pa/l ('p', 'a/l', 'a', 'l', '')
# x6/12 ('x', '6/12', '6', '12', '')
# s14 ('s', '', '', '', '14')
# x9/1 ('x', '9/1', '9', '1', '')
# pp/g ('p', 'p/g', 'p', 'g', '')
# x0/4 ('x', '0/4', '0', '4', '')
# s4 ('s', '', '', '', '4')
# x10/14 ('x', '10/14', '10', '14', '')
# po/i ('p', 'o/i', 'o', 'i', '')
# s2 ('s', '', '', '', '2')
# x11/5 ('x', '11/5', '11', '5', '')
# pd/h ('p', 'd/h', 'd', 'h', '')
# x4/14 ('x', '4/14', '4', '14', '')
# pg/a ('p', 'g/a', 'g', 'a', '')
# x9/5 ('x', '9/5', '9', '5', '')
# s14 ('s', '', '', '', '14')
# x14/10 ('x', '14/10', '14', '10', '')
# s9 ('s', '', '', '', '9')
# x0/15 ('x', '0/15', '0', '15', '')
# s11 ('s', '', '', '', '11')
# x13/9 ('x', '13/9', '13', '9', '')
# s7 ('s', '', '', '', '7')
# x0/11 ('x', '0/11', '0', '11', '')
# pf/l ('p', 'f/l', 'f', 'l', '')
# x4/12 ('x', '4/12', '4', '12', '')
# s3 ('s', '', '', '', '3')
# x5/0 ('x', '5/0', '5', '0', '')
# ph/a ('p', 'h/a', 'h', 'a', '')
# x15/7 ('x', '15/7', '15', '7', '')
# s11 ('s', '', '', '', '11')
# x0/5 ('x', '0/5', '0', '5', '')
# s11 ('s', '', '', '', '11')
# x14/15 ('x', '14/15', '14', '15', '')
# s10 ('s', '', '', '', '10')
# x12/11 ('x', '12/11', '12', '11', '')
# s10 ('s', '', '', '', '10')
# x14/10 ('x', '14/10', '14', '10', '')
# s15 ('s', '', '', '', '15')
# x5/4 ('x', '5/4', '5', '4', '')
# s5 ('s', '', '', '', '5')
# x8/10 ('x', '8/10', '8', '10', '')
# s14 ('s', '', '', '', '14')
# x9/0 ('x', '9/0', '9', '0', '')
# s4 ('s', '', '', '', '4')
# x11/1 ('x', '11/1', '11', '1', '')
# s2 ('s', '', '', '', '2')
# x9/14 ('x', '9/14', '9', '14', '')
# pe/c ('p', 'e/c', 'e', 'c', '')
# x6/13 ('x', '6/13', '6', '13', '')
# ph/a ('p', 'h/a', 'h', 'a', '')
# x7/9 ('x', '7/9', '7', '9', '')
# pi/l ('p', 'i/l', 'i', 'l', '')
# x8/2 ('x', '8/2', '8', '2', '')
# s9 ('s', '', '', '', '9')
# x15/3 ('x', '15/3', '15', '3', '')
# pn/h ('p', 'n/h', 'n', 'h', '')
# x9/13 ('x', '9/13', '9', '13', '')
# s9 ('s', '', '', '', '9')
# x0/4 ('x', '0/4', '0', '4', '')
# s6 ('s', '', '', '', '6')
# x11/2 ('x', '11/2', '11', '2', '')
# s7 ('s', '', '', '', '7')
# x15/14 ('x', '15/14', '15', '14', '')
# pm/l ('p', 'm/l', 'm', 'l', '')
# s2 ('s', '', '', '', '2')
# x0/7 ('x', '0/7', '0', '7', '')
# pb/e ('p', 'b/e', 'b', 'e', '')
# x15/4 ('x', '15/4', '15', '4', '')
# pc/k ('p', 'c/k', 'c', 'k', '')
# s1 ('s', '', '', '', '1')
# x11/5 ('x', '11/5', '11', '5', '')
# pg/e ('p', 'g/e', 'g', 'e', '')
# x7/14 ('x', '7/14', '7', '14', '')
# ph/f ('p', 'h/f', 'h', 'f', '')
# x6/11 ('x', '6/11', '6', '11', '')
# pd/a ('p', 'd/a', 'd', 'a', '')
# x13/4 ('x', '13/4', '13', '4', '')
# s11 ('s', '', '', '', '11')
# x14/2 ('x', '14/2', '14', '2', '')
# pn/l ('p', 'n/l', 'n', 'l', '')
# x0/8 ('x', '0/8', '0', '8', '')
# pe/g ('p', 'e/g', 'e', 'g', '')
# x5/1 ('x', '5/1', '5', '1', '')
# s5 ('s', '', '', '', '5')
# x9/8 ('x', '9/8', '9', '8', '')
# pd/j ('p', 'd/j', 'd', 'j', '')
# x15/10 ('x', '15/10', '15', '10', '')
# s10 ('s', '', '', '', '10')
# x1/4 ('x', '1/4', '1', '4', '')
# po/c ('p', 'o/c', 'o', 'c', '')
# x6/2 ('x', '6/2', '6', '2', '')
# pj/p ('p', 'j/p', 'j', 'p', '')
# x5/7 ('x', '5/7', '5', '7', '')
# s8 ('s', '', '', '', '8')
# x9/10 ('x', '9/10', '9', '10', '')
# pd/h ('p', 'd/h', 'd', 'h', '')
# x5/11 ('x', '5/11', '5', '11', '')
# s4 ('s', '', '', '', '4')
# x13/7 ('x', '13/7', '13', '7', '')
# pj/m ('p', 'j/m', 'j', 'm', '')
# x6/1 ('x', '6/1', '6', '1', '')
# pp/h ('p', 'p/h', 'p', 'h', '')
# s3 ('s', '', '', '', '3')
# x8/12 ('x', '8/12', '8', '12', '')
# s14 ('s', '', '', '', '14')
# pl/g ('p', 'l/g', 'l', 'g', '')
# x10/14 ('x', '10/14', '10', '14', '')
# pd/c ('p', 'd/c', 'd', 'c', '')
# x0/8 ('x', '0/8', '0', '8', '')
# pp/g ('p', 'p/g', 'p', 'g', '')
# x10/7 ('x', '10/7', '10', '7', '')
# s4 ('s', '', '', '', '4')
# x1/3 ('x', '1/3', '1', '3', '')
# s2 ('s', '', '', '', '2')
# x6/0 ('x', '6/0', '6', '0', '')
# pd/a ('p', 'd/a', 'd', 'a', '')
# s1 ('s', '', '', '', '1')
# x3/7 ('x', '3/7', '3', '7', '')
# s12 ('s', '', '', '', '12')
# x9/14 ('x', '9/14', '9', '14', '')
# s15 ('s', '', '', '', '15')
# x2/10 ('x', '2/10', '2', '10', '')
# pp/k ('p', 'p/k', 'p', 'k', '')
# s7 ('s', '', '', '', '7')
# x11/1 ('x', '11/1', '11', '1', '')
# s10 ('s', '', '', '', '10')
# x10/15 ('x', '10/15', '10', '15', '')
# pj/c ('p', 'j/c', 'j', 'c', '')
# x11/14 ('x', '11/14', '11', '14', '')
# pb/g ('p', 'b/g', 'b', 'g', '')
# s8 ('s', '', '', '', '8')
# x0/8 ('x', '0/8', '0', '8', '')
# pj/f ('p', 'j/f', 'j', 'f', '')
# x7/11 ('x', '7/11', '7', '11', '')
# pp/d ('p', 'p/d', 'p', 'd', '')
# s13 ('s', '', '', '', '13')
# x3/10 ('x', '3/10', '3', '10', '')
# s13 ('s', '', '', '', '13')
# x1/15 ('x', '1/15', '1', '15', '')
# pb/k ('p', 'b/k', 'b', 'k', '')
# x3/6 ('x', '3/6', '3', '6', '')
# pg/e ('p', 'g/e', 'g', 'e', '')
# x7/12 ('x', '7/12', '7', '12', '')
# s6 ('s', '', '', '', '6')
# x6/13 ('x', '6/13', '6', '13', '')
# s11 ('s', '', '', '', '11')
# x9/8 ('x', '9/8', '9', '8', '')
# pj/p ('p', 'j/p', 'j', 'p', '')
# x3/10 ('x', '3/10', '3', '10', '')
# s6 ('s', '', '', '', '6')
# x13/11 ('x', '13/11', '13', '11', '')
# s11 ('s', '', '', '', '11')
# x14/7 ('x', '14/7', '14', '7', '')
# s12 ('s', '', '', '', '12')
# x3/13 ('x', '3/13', '3', '13', '')
# s9 ('s', '', '', '', '9')
# x7/11 ('x', '7/11', '7', '11', '')
# s2 ('s', '', '', '', '2')
# pd/a ('p', 'd/a', 'd', 'a', '')
# x4/0 ('x', '4/0', '4', '0', '')
# s5 ('s', '', '', '', '5')
# x2/14 ('x', '2/14', '2', '14', '')
# po/n ('p', 'o/n', 'o', 'n', '')
# x15/10 ('x', '15/10', '15', '10', '')
# s14 ('s', '', '', '', '14')
# x9/4 ('x', '9/4', '9', '4', '')
# pb/p ('p', 'b/p', 'b', 'p', '')
# x12/5 ('x', '12/5', '12', '5', '')
# s10 ('s', '', '', '', '10')
# x13/4 ('x', '13/4', '13', '4', '')
# s15 ('s', '', '', '', '15')
# x14/8 ('x', '14/8', '14', '8', '')
# s7 ('s', '', '', '', '7')
# x1/9 ('x', '1/9', '1', '9', '')
# s3 ('s', '', '', '', '3')
# x15/5 ('x', '15/5', '15', '5', '')
# pf/j ('p', 'f/j', 'f', 'j', '')
# x7/14 ('x', '7/14', '7', '14', '')
# s11 ('s', '', '', '', '11')
# x5/1 ('x', '5/1', '5', '1', '')
# s6 ('s', '', '', '', '6')
# x8/15 ('x', '8/15', '8', '15', '')
# po/c ('p', 'o/c', 'o', 'c', '')
# x6/5 ('x', '6/5', '6', '5', '')
# s8 ('s', '', '', '', '8')
# x1/12 ('x', '1/12', '1', '12', '')
# s7 ('s', '', '', '', '7')
# x2/9 ('x', '2/9', '2', '9', '')
# s9 ('s', '', '', '', '9')
# x4/8 ('x', '4/8', '4', '8', '')
# pa/f ('p', 'a/f', 'a', 'f', '')
# s4 ('s', '', '', '', '4')
# pe/b ('p', 'e/b', 'e', 'b', '')
# x5/1 ('x', '5/1', '5', '1', '')
# s9 ('s', '', '', '', '9')
# x15/7 ('x', '15/7', '15', '7', '')
# s11 ('s', '', '', '', '11')
# x5/2 ('x', '5/2', '5', '2', '')
# pm/i ('p', 'm/i', 'm', 'i', '')
# s3 ('s', '', '', '', '3')
# x9/7 ('x', '9/7', '9', '7', '')
# s10 ('s', '', '', '', '10')
# x2/10 ('x', '2/10', '2', '10', '')
# pg/h ('p', 'g/h', 'g', 'h', '')
# x11/5 ('x', '11/5', '11', '5', '')
# pf/i ('p', 'f/i', 'f', 'i', '')
# x14/1 ('x', '14/1', '14', '1', '')
# pd/k ('p', 'd/k', 'd', 'k', '')
# s4 ('s', '', '', '', '4')
# x8/11 ('x', '8/11', '8', '11', '')
# s10 ('s', '', '', '', '10')
# x7/12 ('x', '7/12', '7', '12', '')
# s6 ('s', '', '', '', '6')
# x4/2 ('x', '4/2', '4', '2', '')
# pp/j ('p', 'p/j', 'p', 'j', '')
# x6/8 ('x', '6/8', '6', '8', '')
# pd/l ('p', 'd/l', 'd', 'l', '')
# x4/13 ('x', '4/13', '4', '13', '')
# s4 ('s', '', '', '', '4')
# x1/12 ('x', '1/12', '1', '12', '')
# pf/o ('p', 'f/o', 'f', 'o', '')
# x6/0 ('x', '6/0', '6', '0', '')
# s4 ('s', '', '', '', '4')
# x4/14 ('x', '4/14', '4', '14', '')
# pm/l ('p', 'm/l', 'm', 'l', '')
# x2/10 ('x', '2/10', '2', '10', '')
# s11 ('s', '', '', '', '11')
# x4/11 ('x', '4/11', '4', '11', '')
# pa/i ('p', 'a/i', 'a', 'i', '')
# x7/2 ('x', '7/2', '7', '2', '')
# pd/f ('p', 'd/f', 'd', 'f', '')
# x1/10 ('x', '1/10', '1', '10', '')
# po/a ('p', 'o/a', 'o', 'a', '')
# x12/0 ('x', '12/0', '12', '0', '')
# s2 ('s', '', '', '', '2')
# x9/13 ('x', '9/13', '9', '13', '')
# pb/n ('p', 'b/n', 'b', 'n', '')
# x5/10 ('x', '5/10', '5', '10', '')
# s4 ('s', '', '', '', '4')
# x6/3 ('x', '6/3', '6', '3', '')
# s9 ('s', '', '', '', '9')
# pa/c ('p', 'a/c', 'a', 'c', '')
# x15/7 ('x', '15/7', '15', '7', '')
# pl/k ('p', 'l/k', 'l', 'k', '')
# s9 ('s', '', '', '', '9')
# x12/1 ('x', '12/1', '12', '1', '')
# s5 ('s', '', '', '', '5')
# po/a ('p', 'o/a', 'o', 'a', '')
# x5/7 ('x', '5/7', '5', '7', '')
# ph/f ('p', 'h/f', 'h', 'f', '')
# x6/14 ('x', '6/14', '6', '14', '')
# s1 ('s', '', '', '', '1')
# x11/13 ('x', '11/13', '11', '13', '')
# s1 ('s', '', '', '', '1')
# x0/3 ('x', '0/3', '0', '3', '')
# s9 ('s', '', '', '', '9')
# x2/9 ('x', '2/9', '2', '9', '')
# pc/e ('p', 'c/e', 'c', 'e', '')
# s14 ('s', '', '', '', '14')
# x15/11 ('x', '15/11', '15', '11', '')
# s2 ('s', '', '', '', '2')
# x5/10 ('x', '5/10', '5', '10', '')
# pp/i ('p', 'p/i', 'p', 'i', '')
# s7 ('s', '', '', '', '7')
# x7/13 ('x', '7/13', '7', '13', '')
# pe/h ('p', 'e/h', 'e', 'h', '')
# x4/6 ('x', '4/6', '4', '6', '')
# pc/l ('p', 'c/l', 'c', 'l', '')
# s2 ('s', '', '', '', '2')
# x1/0 ('x', '1/0', '1', '0', '')
# pn/b ('p', 'n/b', 'n', 'b', '')
# s12 ('s', '', '', '', '12')
# x10/12 ('x', '10/12', '10', '12', '')
# po/a ('p', 'o/a', 'o', 'a', '')
# s7 ('s', '', '', '', '7')
# x13/5 ('x', '13/5', '13', '5', '')
# s5 ('s', '', '', '', '5')
# x12/6 ('x', '12/6', '12', '6', '')
# pp/f ('p', 'p/f', 'p', 'f', '')
# x2/8 ('x', '2/8', '2', '8', '')
# s12 ('s', '', '', '', '12')
# x4/9 ('x', '4/9', '4', '9', '')
# s2 ('s', '', '', '', '2')
# x11/8 ('x', '11/8', '11', '8', '')
# s5 ('s', '', '', '', '5')
# x13/2 ('x', '13/2', '13', '2', '')
# pd/c ('p', 'd/c', 'd', 'c', '')
# x14/4 ('x', '14/4', '14', '4', '')
# pa/e ('p', 'a/e', 'a', 'e', '')
# x8/1 ('x', '8/1', '8', '1', '')
# s12 ('s', '', '', '', '12')
# po/p ('p', 'o/p', 'o', 'p', '')
# s13 ('s', '', '', '', '13')
# x7/6 ('x', '7/6', '7', '6', '')
# pb/l ('p', 'b/l', 'b', 'l', '')
# x0/2 ('x', '0/2', '0', '2', '')
# pf/o ('p', 'f/o', 'f', 'o', '')
# x4/3 ('x', '4/3', '4', '3', '')
# s4 ('s', '', '', '', '4')
# x8/0 ('x', '8/0', '8', '0', '')
# ph/e ('p', 'h/e', 'h', 'e', '')
# s15 ('s', '', '', '', '15')
# x5/2 ('x', '5/2', '5', '2', '')
# po/c ('p', 'o/c', 'o', 'c', '')
# x7/1 ('x', '7/1', '7', '1', '')
# s7 ('s', '', '', '', '7')
# x2/9 ('x', '2/9', '2', '9', '')
# pl/h ('p', 'l/h', 'l', 'h', '')
# x11/5 ('x', '11/5', '11', '5', '')
# s8 ('s', '', '', '', '8')
# x6/4 ('x', '6/4', '6', '4', '')
# s6 ('s', '', '', '', '6')
# x15/0 ('x', '15/0', '15', '0', '')
# s5 ('s', '', '', '', '5')
# x11/13 ('x', '11/13', '11', '13', '')
# s2 ('s', '', '', '', '2')
# x14/0 ('x', '14/0', '14', '0', '')
# pm/g ('p', 'm/g', 'm', 'g', '')
# x13/2 ('x', '13/2', '13', '2', '')
# pa/p ('p', 'a/p', 'a', 'p', '')
# x11/0 ('x', '11/0', '11', '0', '')
# s6 ('s', '', '', '', '6')
# x5/9 ('x', '5/9', '5', '9', '')
# s14 ('s', '', '', '', '14')
# x3/1 ('x', '3/1', '3', '1', '')
# s8 ('s', '', '', '', '8')
# x8/14 ('x', '8/14', '8', '14', '')
# s1 ('s', '', '', '', '1')
# x10/13 ('x', '10/13', '10', '13', '')
# pl/i ('p', 'l/i', 'l', 'i', '')
# x12/6 ('x', '12/6', '12', '6', '')
# s12 ('s', '', '', '', '12')
# x11/13 ('x', '11/13', '11', '13', '')
# pd/k ('p', 'd/k', 'd', 'k', '')
# s1 ('s', '', '', '', '1')
# x15/8 ('x', '15/8', '15', '8', '')
# s2 ('s', '', '', '', '2')
# x13/5 ('x', '13/5', '13', '5', '')
# s7 ('s', '', '', '', '7')
# pm/i ('p', 'm/i', 'm', 'i', '')
# x1/14 ('x', '1/14', '1', '14', '')
# s7 ('s', '', '', '', '7')
# x3/9 ('x', '3/9', '3', '9', '')
# pe/b ('p', 'e/b', 'e', 'b', '')
# x0/5 ('x', '0/5', '0', '5', '')
# pg/n ('p', 'g/n', 'g', 'n', '')
# x4/6 ('x', '4/6', '4', '6', '')
# s13 ('s', '', '', '', '13')
# x7/12 ('x', '7/12', '7', '12', '')
# pj/l ('p', 'j/l', 'j', 'l', '')
# x3/13 ('x', '3/13', '3', '13', '')
# s1 ('s', '', '', '', '1')
# x11/2 ('x', '11/2', '11', '2', '')
# s2 ('s', '', '', '', '2')
# x15/7 ('x', '15/7', '15', '7', '')
# s12 ('s', '', '', '', '12')
# x4/11 ('x', '4/11', '4', '11', '')
# s6 ('s', '', '', '', '6')
# x3/7 ('x', '3/7', '3', '7', '')
# pn/c ('p', 'n/c', 'n', 'c', '')
# x0/1 ('x', '0/1', '0', '1', '')
# pa/e ('p', 'a/e', 'a', 'e', '')
# x10/13 ('x', '10/13', '10', '13', '')
# s10 ('s', '', '', '', '10')
# x15/11 ('x', '15/11', '15', '11', '')
# pd/k ('p', 'd/k', 'd', 'k', '')
# x4/13 ('x', '4/13', '4', '13', '')
# s11 ('s', '', '', '', '11')
# x0/15 ('x', '0/15', '0', '15', '')
# s4 ('s', '', '', '', '4')
# x3/12 ('x', '3/12', '3', '12', '')
# s7 ('s', '', '', '', '7')
# x15/1 ('x', '15/1', '15', '1', '')
# s12 ('s', '', '', '', '12')
# x8/7 ('x', '8/7', '8', '7', '')
# s12 ('s', '', '', '', '12')
# x13/14 ('x', '13/14', '13', '14', '')
# s2 ('s', '', '', '', '2')
# x5/3 ('x', '5/3', '5', '3', '')
# pl/i ('p', 'l/i', 'l', 'i', '')
# s9 ('s', '', '', '', '9')
# x14/6 ('x', '14/6', '14', '6', '')
# pg/j ('p', 'g/j', 'g', 'j', '')
# x0/1 ('x', '0/1', '0', '1', '')
# s2 ('s', '', '', '', '2')
# x5/14 ('x', '5/14', '5', '14', '')
# s15 ('s', '', '', '', '15')
# x15/9 ('x', '15/9', '15', '9', '')
# s15 ('s', '', '', '', '15')
# x0/2 ('x', '0/2', '0', '2', '')
# s1 ('s', '', '', '', '1')
# x11/8 ('x', '11/8', '11', '8', '')
# s4 ('s', '', '', '', '4')
# x5/3 ('x', '5/3', '5', '3', '')
# pc/b ('p', 'c/b', 'c', 'b', '')
# x12/1 ('x', '12/1', '12', '1', '')
# s5 ('s', '', '', '', '5')
# x2/5 ('x', '2/5', '2', '5', '')
# s6 ('s', '', '', '', '6')
# pj/m ('p', 'j/m', 'j', 'm', '')
# x3/7 ('x', '3/7', '3', '7', '')
# pp/c ('p', 'p/c', 'p', 'c', '')
# x13/4 ('x', '13/4', '13', '4', '')
# s9 ('s', '', '', '', '9')
# x5/3 ('x', '5/3', '5', '3', '')
# s14 ('s', '', '', '', '14')
# x4/7 ('x', '4/7', '4', '7', '')
# s14 ('s', '', '', '', '14')
# x0/12 ('x', '0/12', '0', '12', '')
# s1 ('s', '', '', '', '1')
# pm/l ('p', 'm/l', 'm', 'l', '')
# x4/3 ('x', '4/3', '4', '3', '')
# s4 ('s', '', '', '', '4')
# x12/15 ('x', '12/15', '12', '15', '')
# s2 ('s', '', '', '', '2')
# x6/5 ('x', '6/5', '6', '5', '')
# s12 ('s', '', '', '', '12')
# x10/14 ('x', '10/14', '10', '14', '')
# s11 ('s', '', '', '', '11')
# x1/7 ('x', '1/7', '1', '7', '')
# pb/o ('p', 'b/o', 'b', 'o', '')
# x6/4 ('x', '6/4', '6', '4', '')
# pa/d ('p', 'a/d', 'a', 'd', '')
# x8/14 ('x', '8/14', '8', '14', '')
# s14 ('s', '', '', '', '14')
# x11/3 ('x', '11/3', '11', '3', '')
# s13 ('s', '', '', '', '13')
# x13/5 ('x', '13/5', '13', '5', '')
# pk/j ('p', 'k/j', 'k', 'j', '')
# x8/15 ('x', '8/15', '8', '15', '')
# pp/h ('p', 'p/h', 'p', 'h', '')
# x9/1 ('x', '9/1', '9', '1', '')
# s5 ('s', '', '', '', '5')
# x12/0 ('x', '12/0', '12', '0', '')
# s6 ('s', '', '', '', '6')
# x3/11 ('x', '3/11', '3', '11', '')
# po/c ('p', 'o/c', 'o', 'c', '')
# x2/10 ('x', '2/10', '2', '10', '')
# s2 ('s', '', '', '', '2')
# x3/13 ('x', '3/13', '3', '13', '')
# pf/d ('p', 'f/d', 'f', 'd', '')
# x11/4 ('x', '11/4', '11', '4', '')
# s14 ('s', '', '', '', '14')
# x8/15 ('x', '8/15', '8', '15', '')
# pl/h ('p', 'l/h', 'l', 'h', '')
# x4/10 ('x', '4/10', '4', '10', '')
# s9 ('s', '', '', '', '9')
# x13/9 ('x', '13/9', '13', '9', '')
# s10 ('s', '', '', '', '10')
# ...
# pf/c ('p', 'f/c', 'f', 'c', '')
# s5 ('s', '', '', '', '5')
# x0/6 ('x', '0/6', '0', '6', '')
# s6 ('s', '', '', '', '6')
# x14/11 ('x', '14/11', '14', '11', '')
# ph/g ('p', 'h/g', 'h', 'g', '')
# s11 ('s', '', '', '', '11')
# x3/4 ('x', '3/4', '3', '4', '')
# pl/k ('p', 'l/k', 'l', 'k', '')
# x10/12 ('x', '10/12', '10', '12', '')
# s8 ('s', '', '', '', '8')
# x15/5 ('x', '15/5', '15', '5', '')
# s11 ('s', '', '', '', '11')
# x12/9 ('x', '12/9', '12', '9', '')
# pi/h ('p', 'i/h', 'i', 'h', '')
# s1 ('s', '', '', '', '1')
# x3/14 ('x', '3/14', '3', '14', '')
# pg/p ('p', 'g/p', 'g', 'p', '')
# x6/5 ('x', '6/5', '6', '5', '')
# s10 ('s', '', '', '', '10')
# x3/4 ('x', '3/4', '3', '4', '')
# s11 ('s', '', '', '', '11')
# x1/10 ('x', '1/10', '1', '10', '')
# pk/d ('p', 'k/d', 'k', 'd', '')
# s10 ('s', '', '', '', '10')
# x5/9 ('x', '5/9', '5', '9', '')
# pe/p ('p', 'e/p', 'e', 'p', '')
# x14/6 ('x', '14/6', '14', '6', '')
# s10 ('s', '', '', '', '10')
# pb/m ('p', 'b/m', 'b', 'm', '')
# x0/10 ('x', '0/10', '0', '10', '')
# s3 ('s', '', '', '', '3')
# x6/7 ('x', '6/7', '6', '7', '')
# pf/o ('p', 'f/o', 'f', 'o', '')
# x9/3 ('x', '9/3', '9', '3', '')
# s14 ('s', '', '', '', '14')
# ph/m ('p', 'h/m', 'h', 'm', '')
# s2 ('s', '', '', '', '2')
# x15/6 ('x', '15/6', '15', '6', '')
# pn/a ('p', 'n/a', 'n', 'a', '')
# x4/13 ('x', '4/13', '4', '13', '')
# pc/l ('p', 'c/l', 'c', 'l', '')
# x14/2 ('x', '14/2', '14', '2', '')
# s14 ('s', '', '', '', '14')
# x3/13 ('x', '3/13', '3', '13', '')
# s9 ('s', '', '', '', '9')
# x8/0 ('x', '8/0', '8', '0', '')
# po/m ('p', 'o/m', 'o', 'm', '')
# x7/6 ('x', '7/6', '7', '6', '')
# pp/j ('p', 'p/j', 'p', 'j', '')
# x12/15 ('x', '12/15', '12', '15', '')
# s3 ('s', '', '', '', '3')
# x1/9 ('x', '1/9', '1', '9', '')
# s10 ('s', '', '', '', '10')
# x5/8 ('x', '5/8', '5', '8', '')
# s6 ('s', '', '', '', '6')
# x6/13 ('x', '6/13', '6', '13', '')
# s5 ('s', '', '', '', '5')
# x5/1 ('x', '5/1', '5', '1', '')
# pd/a ('p', 'd/a', 'd', 'a', '')
# x2/12 ('x', '2/12', '2', '12', '')
# s11 ('s', '', '', '', '11')
# x8/3 ('x', '8/3', '8', '3', '')
# s8 ('s', '', '', '', '8')
# pp/m ('p', 'p/m', 'p', 'm', '')
# x11/0 ('x', '11/0', '11', '0', '')
# s6 ('s', '', '', '', '6')
# x2/14 ('x', '2/14', '2', '14', '')
# s15 ('s', '', '', '', '15')
# x12/13 ('x', '12/13', '12', '13', '')
# s15 ('s', '', '', '', '15')
# x9/8 ('x', '9/8', '9', '8', '')
# s13 ('s', '', '', '', '13')
# x15/12 ('x', '15/12', '15', '12', '')
# s6 ('s', '', '', '', '6')
# x14/8 ('x', '14/8', '14', '8', '')
# s9 ('s', '', '', '', '9')
# x9/2 ('x', '9/2', '9', '2', '')
# s3 ('s', '', '', '', '3')
# x14/7 ('x', '14/7', '14', '7', '')
# s12 ('s', '', '', '', '12')
# x1/11 ('x', '1/11', '1', '11', '')
# s4 ('s', '', '', '', '4')
# x13/2 ('x', '13/2', '13', '2', '')
# s5 ('s', '', '', '', '5')
# x12/10 ('x', '12/10', '12', '10', '')
# s14 ('s', '', '', '', '14')
# x1/8 ('x', '1/8', '1', '8', '')
# pe/a ('p', 'e/a', 'e', 'a', '')
# x0/4 ('x', '0/4', '0', '4', '')
# pi/o ('p', 'i/o', 'i', 'o', '')
# x5/10 ('x', '5/10', '5', '10', '')
# s2 ('s', '', '', '', '2')
# x0/3 ('x', '0/3', '0', '3', '')
# pd/f ('p', 'd/f', 'd', 'f', '')
# x1/14 ('x', '1/14', '1', '14', '')
# pb/c ('p', 'b/c', 'b', 'c', '')
# x10/2 ('x', '10/2', '10', '2', '')
# s3 ('s', '', '', '', '3')
# x0/13 ('x', '0/13', '0', '13', '')
# s14 ('s', '', '', '', '14')
# x14/2 ('x', '14/2', '14', '2', '')
# s7 ('s', '', '', '', '7')
# x13/7 ('x', '13/7', '13', '7', '')
# s13 ('s', '', '', '', '13')
# x12/11 ('x', '12/11', '12', '11', '')
# pf/a ('p', 'f/a', 'f', 'a', '')
# x14/1 ('x', '14/1', '14', '1', '')
# ph/m ('p', 'h/m', 'h', 'm', '')
# x8/11 ('x', '8/11', '8', '11', '')
# s12 ('s', '', '', '', '12')
# x13/5 ('x', '13/5', '13', '5', '')
# pn/p ('p', 'n/p', 'n', 'p', '')
# x1/8 ('x', '1/8', '1', '8', '')
# s7 ('s', '', '', '', '7')
# pd/l ('p', 'd/l', 'd', 'l', '')
# x12/4 ('x', '12/4', '12', '4', '')
# s4 ('s', '', '', '', '4')
# x10/6 ('x', '10/6', '10', '6', '')
# s3 ('s', '', '', '', '3')
# x7/5 ('x', '7/5', '7', '5', '')
# s6 ('s', '', '', '', '6')
# pn/j ('p', 'n/j', 'n', 'j', '')
# x12/13 ('x', '12/13', '12', '13', '')
# pe/f ('p', 'e/f', 'e', 'f', '')
# x4/10 ('x', '4/10', '4', '10', '')
# pd/g ('p', 'd/g', 'd', 'g', '')
# x6/14 ('x', '6/14', '6', '14', '')
# ph/p ('p', 'h/p', 'h', 'p', '')
# x5/13 ('x', '5/13', '5', '13', '')
# s3 ('s', '', '', '', '3')
# x15/1 ('x', '15/1', '15', '1', '')
# s14 ('s', '', '', '', '14')
# x7/2 ('x', '7/2', '7', '2', '')
# pb/a ('p', 'b/a', 'b', 'a', '')
# x4/13 ('x', '4/13', '4', '13', '')
# pc/o ('p', 'c/o', 'c', 'o', '')
# x5/6 ('x', '5/6', '5', '6', '')
# s10 ('s', '', '', '', '10')
# x12/15 ('x', '12/15', '12', '15', '')
# pe/j ('p', 'e/j', 'e', 'j', '')
# x4/6 ('x', '4/6', '4', '6', '')
# s15 ('s', '', '', '', '15')
# x9/13 ('x', '9/13', '9', '13', '')
# s10 ('s', '', '', '', '10')
# pg/h ('p', 'g/h', 'g', 'h', '')
# x3/11 ('x', '3/11', '3', '11', '')
# s8 ('s', '', '', '', '8')
# x9/6 ('x', '9/6', '9', '6', '')
# s11 ('s', '', '', '', '11')
# x0/12 ('x', '0/12', '0', '12', '')
# pm/a ('p', 'm/a', 'm', 'a', '')
# s2 ('s', '', '', '', '2')
# x2/7 ('x', '2/7', '2', '7', '')
# s13 ('s', '', '', '', '13')
# x11/12 ('x', '11/12', '11', '12', '')
# s5 ('s', '', '', '', '5')
# x2/13 ('x', '2/13', '2', '13', '')
# s8 ('s', '', '', '', '8')
# x5/14 ('x', '5/14', '5', '14', '')
# s3 ('s', '', '', '', '3')
# x3/13 ('x', '3/13', '3', '13', '')
# s6 ('s', '', '', '', '6')
# x4/6 ('x', '4/6', '4', '6', '')
# pe/o ('p', 'e/o', 'e', 'o', '')
# x3/10 ('x', '3/10', '3', '10', '')
# pm/g ('p', 'm/g', 'm', 'g', '')
# x0/12 ('x', '0/12', '0', '12', '')
# s8 ('s', '', '', '', '8')
# x8/9 ('x', '8/9', '8', '9', '')
# s9 ('s', '', '', '', '9')
# x13/14 ('x', '13/14', '13', '14', '')
# s5 ('s', '', '', '', '5')
# x8/3 ('x', '8/3', '8', '3', '')
# s11 ('s', '', '', '', '11')
# x5/7 ('x', '5/7', '5', '7', '')
# pk/d ('p', 'k/d', 'k', 'd', '')
# x14/6 ('x', '14/6', '14', '6', '')
# s10 ('s', '', '', '', '10')
# x4/1 ('x', '4/1', '4', '1', '')
# s9 ('s', '', '', '', '9')
# x7/12 ('x', '7/12', '7', '12', '')
# s9 ('s', '', '', '', '9')
# x9/3 ('x', '9/3', '9', '3', '')
# pm/p ('p', 'm/p', 'm', 'p', '')
# x15/10 ('x', '15/10', '15', '10', '')
# s11 ('s', '', '', '', '11')
# x6/0 ('x', '6/0', '6', '0', '')
# s3 ('s', '', '', '', '3')
# x8/2 ('x', '8/2', '8', '2', '')
# pg/l ('p', 'g/l', 'g', 'l', '')
# x6/7 ('x', '6/7', '6', '7', '')
# pf/a ('p', 'f/a', 'f', 'a', '')
# s10 ('s', '', '', '', '10')
# pi/e ('p', 'i/e', 'i', 'e', '')
# s3 ('s', '', '', '', '3')
# x4/0 ('x', '4/0', '4', '0', '')
# s12 ('s', '', '', '', '12')
# x13/3 ('x', '13/3', '13', '3', '')
# s1 ('s', '', '', '', '1')
# x2/5 ('x', '2/5', '2', '5', '')
# pm/b ('p', 'm/b', 'm', 'b', '')
# x0/9 ('x', '0/9', '0', '9', '')
# s8 ('s', '', '', '', '8')
# x15/4 ('x', '15/4', '15', '4', '')
# s9 ('s', '', '', '', '9')
# x11/3 ('x', '11/3', '11', '3', '')
# pe/j ('p', 'e/j', 'e', 'j', '')
# x7/2 ('x', '7/2', '7', '2', '')
# s4 ('s', '', '', '', '4')
# x13/0 ('x', '13/0', '13', '0', '')
# s10 ('s', '', '', '', '10')
# x11/6 ('x', '11/6', '11', '6', '')
# pa/p ('p', 'a/p', 'a', 'p', '')
# x3/4 ('x', '3/4', '3', '4', '')
# pf/o ('p', 'f/o', 'f', 'o', '')
# x10/1 ('x', '10/1', '10', '1', '')
# s2 ('s', '', '', '', '2')
# x12/6 ('x', '12/6', '12', '6', '')
# pd/a ('p', 'd/a', 'd', 'a', '')
# x9/1 ('x', '9/1', '9', '1', '')
# pg/e ('p', 'g/e', 'g', 'e', '')
# x0/13 ('x', '0/13', '0', '13', '')
# s4 ('s', '', '', '', '4')
# x14/10 ('x', '14/10', '14', '10', '')
# s12 ('s', '', '', '', '12')
# x13/1 ('x', '13/1', '13', '1', '')
# pk/p ('p', 'k/p', 'k', 'p', '')
# s11 ('s', '', '', '', '11')
# x6/9 ('x', '6/9', '6', '9', '')
# s9 ('s', '', '', '', '9')
# x12/11 ('x', '12/11', '12', '11', '')
# pf/e ('p', 'f/e', 'f', 'e', '')
# x3/0 ('x', '3/0', '3', '0', '')
# ph/g ('p', 'h/g', 'h', 'g', '')
# x12/2 ('x', '12/2', '12', '2', '')
# pf/m ('p', 'f/m', 'f', 'm', '')
# x3/15 ('x', '3/15', '3', '15', '')
# pk/n ('p', 'k/n', 'k', 'n', '')
# x1/10 ('x', '1/10', '1', '10', '')
# pc/d ('p', 'c/d', 'c', 'd', '')
# s13 ('s', '', '', '', '13')
# x7/3 ('x', '7/3', '7', '3', '')
# s11 ('s', '', '', '', '11')
# x2/8 ('x', '2/8', '2', '8', '')
# s2 ('s', '', '', '', '2')
# x1/12 ('x', '1/12', '1', '12', '')
# pg/n ('p', 'g/n', 'g', 'n', '')
# x14/9 ('x', '14/9', '14', '9', '')
# pm/h ('p', 'm/h', 'm', 'h', '')
# x6/1 ('x', '6/1', '6', '1', '')
# s11 ('s', '', '', '', '11')
# pk/p ('p', 'k/p', 'k', 'p', '')
# x5/3 ('x', '5/3', '5', '3', '')
# s13 ('s', '', '', '', '13')
# x8/10 ('x', '8/10', '8', '10', '')
# s10 ('s', '', '', '', '10')
# x9/5 ('x', '9/5', '9', '5', '')
# s2 ('s', '', '', '', '2')
# x3/15 ('x', '3/15', '3', '15', '')
# s9 ('s', '', '', '', '9')
# x8/9 ('x', '8/9', '8', '9', '')
# s12 ('s', '', '', '', '12')
# x4/10 ('x', '4/10', '4', '10', '')
# s1 ('s', '', '', '', '1')
# x2/8 ('x', '2/8', '2', '8', '')
# s1 ('s', '', '', '', '1')
# x12/3 ('x', '12/3', '12', '3', '')
# pl/g ('p', 'l/g', 'l', 'g', '')
# x5/7 ('x', '5/7', '5', '7', '')
# pa/j ('p', 'a/j', 'a', 'j', '')
# x3/4 ('x', '3/4', '3', '4', '')
# s12 ('s', '', '', '', '12')
# x8/2 ('x', '8/2', '8', '2', '')
# s2 ('s', '', '', '', '2')
# x0/4 ('x', '0/4', '0', '4', '')
# pk/d ('p', 'k/d', 'k', 'd', '')
# s9 ('s', '', '', '', '9')
# x8/12 ('x', '8/12', '8', '12', '')
# po/f ('p', 'o/f', 'o', 'f', '')
# x7/3 ('x', '7/3', '7', '3', '')
# pi/p ('p', 'i/p', 'i', 'p', '')
# x15/1 ('x', '15/1', '15', '1', '')
# s10 ('s', '', '', '', '10')
# x14/2 ('x', '14/2', '14', '2', '')
# s9 ('s', '', '', '', '9')
# x13/12 ('x', '13/12', '13', '12', '')
# s11 ('s', '', '', '', '11')
# x9/7 ('x', '9/7', '9', '7', '')
# s7 ('s', '', '', '', '7')
# x1/3 ('x', '1/3', '1', '3', '')
# pj/a ('p', 'j/a', 'j', 'a', '')
# x8/14 ('x', '8/14', '8', '14', '')
# s15 ('s', '', '', '', '15')
# x10/12 ('x', '10/12', '10', '12', '')
# pg/f ('p', 'g/f', 'g', 'f', '')
# x9/11 ('x', '9/11', '9', '11', '')
# s9 ('s', '', '', '', '9')
# x7/3 ('x', '7/3', '7', '3', '')
# pp/c ('p', 'p/c', 'p', 'c', '')
# x2/1 ('x', '2/1', '2', '1', '')
# pm/l ('p', 'm/l', 'm', 'l', '')
# x9/14 ('x', '9/14', '9', '14', '')
# po/k ('p', 'o/k', 'o', 'k', '')
# x12/8 ('x', '12/8', '12', '8', '')
# s11 ('s', '', '', '', '11')
# x1/15 ('x', '1/15', '1', '15', '')
# s6 ('s', '', '', '', '6')
# x8/12 ('x', '8/12', '8', '12', '')
# pl/m ('p', 'l/m', 'l', 'm', '')
# x6/3 ('x', '6/3', '6', '3', '')
# s2 ('s', '', '', '', '2')
# x2/0 ('x', '2/0', '2', '0', '')
# s7 ('s', '', '', '', '7')
# x4/9 ('x', '4/9', '4', '9', '')
# s9 ('s', '', '', '', '9')
# x1/10 ('x', '1/10', '1', '10', '')
# pj/n ('p', 'j/n', 'j', 'n', '')
# x11/13 ('x', '11/13', '11', '13', '')
# pd/b ('p', 'd/b', 'd', 'b', '')
# x9/8 ('x', '9/8', '9', '8', '')
# s12 ('s', '', '', '', '12')
# pc/m ('p', 'c/m', 'c', 'm', '')
# x14/15 ('x', '14/15', '14', '15', '')
# pf/p ('p', 'f/p', 'f', 'p', '')
# x8/11 ('x', '8/11', '8', '11', '')
# s14 ('s', '', '', '', '14')
# x3/13 ('x', '3/13', '3', '13', '')
# s12 ('s', '', '', '', '12')
# x6/2 ('x', '6/2', '6', '2', '')
# s15 ('s', '', '', '', '15')
# x7/13 ('x', '7/13', '7', '13', '')
# pm/j ('p', 'm/j', 'm', 'j', '')
# x3/6 ('x', '3/6', '3', '6', '')
# s9 ('s', '', '', '', '9')
# x10/5 ('x', '10/5', '10', '5', '')
# s7 ('s', '', '', '', '7')
# x2/4 ('x', '2/4', '2', '4', '')
# s12 ('s', '', '', '', '12')
# x14/9 ('x', '14/9', '14', '9', '')
# po/d ('p', 'o/d', 'o', 'd', '')
# x8/10 ('x', '8/10', '8', '10', '')
# s12 ('s', '', '', '', '12')
# x14/4 ('x', '14/4', '14', '4', '')
# s10 ('s', '', '', '', '10')
# x7/13 ('x', '7/13', '7', '13', '')
# s10 ('s', '', '', '', '10')
# x1/8 ('x', '1/8', '1', '8', '')
# s4 ('s', '', '', '', '4')
# x10/4 ('x', '10/4', '10', '4', '')
# pa/g ('p', 'a/g', 'a', 'g', '')
# x2/14 ('x', '2/14', '2', '14', '')
# s8 ('s', '', '', '', '8')
# x6/11 ('x', '6/11', '6', '11', '')
# pi/d ('p', 'i/d', 'i', 'd', '')
# x3/0 ('x', '3/0', '3', '0', '')
# s13 ('s', '', '', '', '13')
# x5/10 ('x', '5/10', '5', '10', '')
# pj/l ('p', 'j/l', 'j', 'l', '')
# x15/13 ('x', '15/13', '15', '13', '')
# s10 ('s', '', '', '', '10')
# pa/f ('p', 'a/f', 'a', 'f', '')
# x1/2 ('x', '1/2', '1', '2', '')
# pb/e ('p', 'b/e', 'b', 'e', '')
# s10 ('s', '', '', '', '10')
# x14/6 ('x', '14/6', '14', '6', '')
# s5 ('s', '', '', '', '5')
# x3/5 ('x', '3/5', '3', '5', '')
# pm/g ('p', 'm/g', 'm', 'g', '')
# x4/1 ('x', '4/1', '4', '1', '')
# pn/p ('p', 'n/p', 'n', 'p', '')
# x2/14 ('x', '2/14', '2', '14', '')
# s4 ('s', '', '', '', '4')
# x12/15 ('x', '12/15', '12', '15', '')
# s12 ('s', '', '', '', '12')
# x7/13 ('x', '7/13', '7', '13', '')
# s1 ('s', '', '', '', '1')
# x11/3 ('x', '11/3', '11', '3', '')
# pg/l ('p', 'g/l', 'g', 'l', '')
# x8/1 ('x', '8/1', '8', '1', '')
# s8 ('s', '', '', '', '8')
# x7/6 ('x', '7/6', '7', '6', '')
# pk/d ('p', 'k/d', 'k', 'd', '')
# s11 ('s', '', '', '', '11')
# x5/11 ('x', '5/11', '5', '11', '')
# s14 ('s', '', '', '', '14')
# x10/2 ('x', '10/2', '10', '2', '')
# pp/e ('p', 'p/e', 'p', 'e', '')
# x6/4 ('x', '6/4', '6', '4', '')
# pd/m ('p', 'd/m', 'd', 'm', '')
# x0/15 ('x', '0/15', '0', '15', '')
# pj/o ('p', 'j/o', 'j', 'o', '')
# x4/7 ('x', '4/7', '4', '7', '')
# s2 ('s', '', '', '', '2')
# x10/8 ('x', '10/8', '10', '8', '')
# s1 ('s', '', '', '', '1')
# x14/2 ('x', '14/2', '14', '2', '')
# s10 ('s', '', '', '', '10')
# x11/12 ('x', '11/12', '11', '12', '')
# s9 ('s', '', '', '', '9')
# x6/4 ('x', '6/4', '6', '4', '')
# s9 ('s', '', '', '', '9')
# x9/15 ('x', '9/15', '9', '15', '')
# s4 ('s', '', '', '', '4')
# x10/13 ('x', '10/13', '10', '13', '')
# ph/p ('p', 'h/p', 'h', 'p', '')
# x0/1 ('x', '0/1', '0', '1', '')
# pa/g ('p', 'a/g', 'a', 'g', '')
# s3 ('s', '', '', '', '3')
# x4/3 ('x', '4/3', '4', '3', '')
# pf/k ('p', 'f/k', 'f', 'k', '')
# x14/0 ('x', '14/0', '14', '0', '')
# pe/j ('p', 'e/j', 'e', 'j', '')
# x10/13 ('x', '10/13', '10', '13', '')
# s7 ('s', '', '', '', '7')
# x9/2 ('x', '9/2', '9', '2', '')
# s4 ('s', '', '', '', '4')
# x3/5 ('x', '3/5', '3', '5', '')
# s8 ('s', '', '', '', '8')
# x12/1 ('x', '12/1', '12', '1', '')
# pa/p ('p', 'a/p', 'a', 'p', '')
# x10/2 ('x', '10/2', '10', '2', '')
# pn/d ('p', 'n/d', 'n', 'd', '')
# x8/5 ('x', '8/5', '8', '5', '')
# s13 ('s', '', '', '', '13')
# x13/4 ('x', '13/4', '13', '4', '')
# s7 ('s', '', '', '', '7')
# x2/3 ('x', '2/3', '2', '3', '')
# pi/b ('p', 'i/b', 'i', 'b', '')
# x8/4 ('x', '8/4', '8', '4', '')
# pp/k ('p', 'p/k', 'p', 'k', '')
# s1 ('s', '', '', '', '1')
# x9/2 ('x', '9/2', '9', '2', '')
# pd/e ('p', 'd/e', 'd', 'e', '')
# s5 ('s', '', '', '', '5')
# x8/7 ('x', '8/7', '8', '7', '')
# s3 ('s', '', '', '', '3')
# x11/12 ('x', '11/12', '11', '12', '')
# po/j ('p', 'o/j', 'o', 'j', '')
# x0/15 ('x', '0/15', '0', '15', '')
# pk/m ('p', 'k/m', 'k', 'm', '')
# x1/6 ('x', '1/6', '1', '6', '')
# po/f ('p', 'o/f', 'o', 'f', '')
# x11/3 ('x', '11/3', '11', '3', '')
# s1 ('s', '', '', '', '1')
# x8/9 ('x', '8/9', '8', '9', '')
# pa/j ('p', 'a/j', 'a', 'j', '')
# x12/5 ('x', '12/5', '12', '5', '')
# pb/k ('p', 'b/k', 'b', 'k', '')
# s9 ('s', '', '', '', '9')
# x14/15 ('x', '14/15', '14', '15', '')
# s6 ('s', '', '', '', '6')
# x6/12 ('x', '6/12', '6', '12', '')
# s8 ('s', '', '', '', '8')
# x1/11 ('x', '1/11', '1', '11', '')
# s6 ('s', '', '', '', '6')
# x3/12 ('x', '3/12', '3', '12', '')
# pd/e ('p', 'd/e', 'd', 'e', '')
# x5/0 ('x', '5/0', '5', '0', '')
# po/h ('p', 'o/h', 'o', 'h', '')
# x11/4 ('x', '11/4', '11', '4', '')
# s13 ('s', '', '', '', '13')
# x14/7 ('x', '14/7', '14', '7', '')
# s11 ('s', '', '', '', '11')
# x5/3 ('x', '5/3', '5', '3', '')
# s8 ('s', '', '', '', '8')
# x12/2 ('x', '12/2', '12', '2', '')
# s10 ('s', '', '', '', '10')
# x15/5 ('x', '15/5', '15', '5', '')
# s13 ('s', '', '', '', '13')
# x3/14 ('x', '3/14', '3', '14', '')
# s1 ('s', '', '', '', '1')
# x11/1 ('x', '11/1', '11', '1', '')
# s3 ('s', '', '', '', '3')
# x13/5 ('x', '13/5', '13', '5', '')
# s7 ('s', '', '', '', '7')
# x8/0 ('x', '8/0', '8', '0', '')
# s13 ('s', '', '', '', '13')
# x4/6 ('x', '4/6', '4', '6', '')
# s15 ('s', '', '', '', '15')
# x7/11 ('x', '7/11', '7', '11', '')
# s1 ('s', '', '', '', '1')
# x15/3 ('x', '15/3', '15', '3', '')
# s13 ('s', '', '', '', '13')
# x4/7 ('x', '4/7', '4', '7', '')
# pe/k ('p', 'e/k', 'e', 'k', '')
# s3 ('s', '', '', '', '3')
# x11/6 ('x', '11/6', '11', '6', '')
# pn/j ('p', 'n/j', 'n', 'j', '')
# x10/0 ('x', '10/0', '10', '0', '')
# pp/l ('p', 'p/l', 'p', 'l', '')
# s13 ('s', '', '', '', '13')
# x7/1 ('x', '7/1', '7', '1', '')
# s1 ('s', '', '', '', '1')
# x0/11 ('x', '0/11', '0', '11', '')
# pb/g ('p', 'b/g', 'b', 'g', '')
# x1/8 ('x', '1/8', '1', '8', '')
# s3 ('s', '', '', '', '3')
# x15/3 ('x', '15/3', '15', '3', '')
# s5 ('s', '', '', '', '5')
# x2/13 ('x', '2/13', '2', '13', '')
# pf/m ('p', 'f/m', 'f', 'm', '')
# x15/1 ('x', '15/1', '15', '1', '')
# s13 ('s', '', '', '', '13')
# x0/13 ('x', '0/13', '0', '13', '')
# pd/i ('p', 'd/i', 'd', 'i', '')
# s4 ('s', '', '', '', '4')
# x10/4 ('x', '10/4', '10', '4', '')
# pa/n ('p', 'a/n', 'a', 'n', '')
# s6 ('s', '', '', '', '6')
